# %% [markdown]
# ###Downloading and Importing Packages

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pytorch_lightning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pytorch_lightning in /usr/local/lib/python3.8/dist-packages (1.8.5.post0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (1.21.6)
# Requirement already satisfied: tensorboardX>=2.2 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (2.5.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (0.11.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (4.4.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (2022.11.0)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (1.13.0+cu116)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (4.64.1)
# Requirement already satisfied: lightning-utilities!=0.4.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (0.4.2)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (6.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (21.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.8/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning) (3.8.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning) (2.23.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (6.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.3.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (2.1.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (4.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=17.0->pytorch_lightning) (3.0.9)
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.8/dist-packages (from tensorboardX>=2.2->pytorch_lightning) (3.19.6)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.8/dist-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (1.24.3)

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

import torch
import torch.nn.functional as F

from torch import nn
from torchvision import transforms
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import h5py
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import torchvision
from functools import partial
import pytorch_lightning as pl
from pytorch_lightning.core.datamodule import LightningDataModule
from torch.utils.data import random_split, DataLoader
from matplotlib.patches import Rectangle
import random
from torch.autograd import Variable

# %% [markdown]
# ###utils

# %%
def MultiApply(func, *args, **kwargs):
    pfunc = partial(func, **kwargs) if kwargs else func
    map_results = map(pfunc, *args)
  
    return tuple(map(list, zip(*map_results)))

# This function compute the IOU between two set of boxes 
def IOU(output, target):
    ##################################
    #TODO compute the IOU between the boxA, boxB boxes
    ##################################
  
    output_box_x1 = output[:, 0] - output[:, 2] / 2
    output_box_y1 = output[:, 1] - output[:, 3] / 2
    output_box_x2 = output[:, 0] + output[:, 2] / 2
    output_box_y2 = output[:, 1] + output[:, 3] / 2
    target_box_x1 = target[:, 0] - target[:, 2] / 2
    target_box_y1 = target[:, 1] - target[:, 3] / 2
    target_box_x2 = target[:, 0] + target[:, 2] / 2
    target_box_y2 = target[:, 1] + target[:, 3] / 2

    x1 = torch.max(output_box_x1, target_box_x1)
    y1 = torch.max(output_box_y1, target_box_y1)
    x2 = torch.min(output_box_x2, target_box_x2)
    y2 = torch.min(output_box_y2, target_box_y2)

    intersection = (x2 - x1).clamp(0) * (y2 - y1).clamp(0)
    output_box_area = target[:, 2] * target[:, 3] 
    target_box_area = output[:, 2] * output[:, 3] 

    return intersection / (output_box_area + target_box_area - intersection + 1e-6)


# This function decodes the output of the box head that are given in the [t_x,t_y,t_w,t_h] format
# into box coordinates where it return the upper left and lower right corner of the bbox
# Input:
#       regressed_boxes_t: (total_proposals,4) ([t_x,t_y,t_w,t_h] format)
#       flatten_proposals: (total_proposals,4) ([x1,y1,x2,y2] format)
# Output:
#       box: (total_proposals,4) ([x1,y1,x2,y2] format)
def output_decoding(out,anchors, device='cpu'):
    #######################################
    # TODO decode the output
    #######################################
    anchors = anchors.cpu()
    box = torch.zeros(out.shape)

    box[0,:,:] = out[0,:,:]*anchors[:,:,2] + anchors[:,:,0]
    box[1,:,:] = out[1,:,:]*anchors[:,:,3] + anchors[:,:,1]
    box[2,:,:] = torch.exp(out[2,:,:])*anchors[:,:,2]
    box[3,:,:] = torch.exp(out[3,:,:])*anchors[:,:,3]
    
    return box

def flattened_output_decoding(flatten_out,flatten_anchors, device='cpu'):
    #######################################
    # TODO decode the output
    #######################################
    flatten_anchors = flatten_anchors.cpu()
    box = torch.zeros(flatten_out.shape)
    box[:, 0] = (flatten_out[:, 0] * flatten_anchors[:, 2]) + flatten_anchors[:,0]
    box[:, 1] = (flatten_out[:, 1] * flatten_anchors[:, 3]) + flatten_anchors[:,1]
    box[:, 2] = torch.exp(flatten_out[:, 2]) * flatten_anchors[:, 2]
    box[:, 3] = torch.exp(flatten_out[:, 3]) * flatten_anchors[:, 3]
    
    return box


def pretrained_models_680(checkpoint_file,eval=True):

    model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=False)

    if(eval):
        model.eval()

    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
    model.to(device)

    backbone = model.backbone
    rpn = model.rpn

    if(eval):
        backbone.eval()
        rpn.eval()

    rpn.nms_thresh=0.6
    checkpoint = torch.load(checkpoint_file)

    backbone.load_state_dict(checkpoint['backbone'])
    rpn.load_state_dict(checkpoint['rpn'])

    return backbone, rpn

# %% [markdown]
# ### Defining dataloaders

# %%
def load_data(paths):
  images_file = h5py.File(paths[0],'r') 
  masks_file = h5py.File(paths[1],'r')
  

  # images = np.array(images_file['data'])
  # masks = np.array(masks_file['data'])
  images = images_file['data']
  masks = masks_file['data']
  bboxes = np.load(paths[3], allow_pickle=True)
  labels = np.load(paths[2], allow_pickle=True)

  label_based_masks = []
  cur_pointer = 0
  for label in labels:
    cur_mask = np.empty((len(label), 300, 400))

    for i in range(len(label)):
      cur_mask[i] = masks[cur_pointer]
      cur_pointer += 1
    label_based_masks.append(cur_mask)

  label_based_masks = np.array(label_based_masks)

  return images, label_based_masks, labels, bboxes

def collate_fn(batch):
    images, labels, masks, bounding_boxes, indices, old_mask = list(zip(*batch))
    return torch.stack(images), labels, masks, bounding_boxes, indices, old_mask

class BuildDataset(Dataset):
    def __init__(self, path, image_transform=None, mask_transform = None):
        #############################################
        # TODO Initialize  Dataset
        #############################################
        self.images, self.masks, self.labels, self.bboxes = load_data(path)

        self.image_transform = image_transform
        self.mask_transform = mask_transform

    # In this function for given index we rescale the image and the corresponding  masks, boxes
    # and we return them as output
    # output:
        # transed_img
        # label
        # transed_mask
        # transed_bbox
        # index
    def __getitem__(self, idx):
        ################################
        # TODO return transformed images,labels,masks,boxes,index
        ################################
        image = self.images[idx].astype('uint8').transpose(1,2,0)
        label = self.labels[idx].astype('float32')
        mask = torch.tensor(self.masks[idx].astype('float64'))
        bbox = self.bboxes[idx].astype('float32')
        
        if self.image_transform:

          image = self.image_transform(image)
          mask = self.mask_transform(mask)
        #   x_scale = 1066.0 / 400.0
        #   y_scale =  800.0 / 300.0
        #   for i, box in enumerate(bbox):
        #     bbox[i][0] = box[0] * x_scale + 11.0
        #     bbox[i][1] = box[1] * y_scale
        #     bbox[i][2] = box[2] * x_scale + 11.0
        #     bbox[i][3] = box[3] * y_scale
          x_scale = 800.0 / 300.0
          y_scale = 1088.0 / 400.0
          for i, box in enumerate(bbox):
            bbox[i][0] = box[0] * x_scale
            bbox[i][1] = box[1] * y_scale
            bbox[i][2] = box[2] * x_scale
            bbox[i][3] = box[3] * y_scale
        old_mask = mask.clone()
        
        # if self.image_transform:
        #   image = self.image_transform(image)
        #   mask = self.mask_transform(mask)
        #   x_scale = 800.0 / 300.0
        #   y_scale =  1088.0 / 400.0
        #   for i, box in enumerate(bbox):
        #     bbox[i][0] = box[0] * x_scale
        #     bbox[i][1] = box[1] * y_scale
        #     bbox[i][2] = box[2] * x_scale
        #     bbox[i][3] = box[3] * y_scale

        bbox = torch.tensor(bbox, device = device)

        target = torch.zeros(3, 28, 28).to(device)
        label_once = []
        # crop mask as bbox
        for idxe in range(bbox.shape[0]):

            # only use the first occurred label
            labe = int(label[idxe])-1
            if labe in label_once:                             
                continue
            label_once.append(labe)

            x1, y1, x2, y2 = bbox[idxe].type(torch.int)        # bbox [4,]
            mas = mask[idxe]                                   # mask [800, 1088]
            mask_cropped = mas[y1:y2, x1:x2]                  
            mask_unsquez = mask_cropped.unsqueeze(0)
            mask_unsquez = mask_unsquez.unsqueeze(0)

            # Resize cropped mask to 28 * 28
            mask_resized = F.interpolate(mask_unsquez, (28, 28), mode='bilinear', align_corners=True)   # [1, 1, 28, 28]
            positive_mask = torch.where(mask_resized > 0)
            # print(label)
            mask_resized[positive_mask] = 1
            target[labe] = mask_resized.squeeze()

        mask_target = target.unsqueeze(0).expand(50, -1, -1, -1)


        assert image.shape == (3,800,1088)
        assert bbox.shape[0] == mask.shape[0]
        
        return image, label, mask_target, bbox, idx, old_mask

    # This function preprocess the given image, mask, box by rescaling them appropriately
    # output:
    #        img: (3,800,1088)
    #        mask: (n_box,800,1088)
    #        box: (n_box,4)
    # def pre_process_batch(self, img, mask, bbox):
    #     #######################################
    #     # TODO apply the correct transformation to the images,masks,boxes
    #     ######################################

    #     assert img.squeeze(0).shape == (3, 800, 1088)
    #     assert bbox.shape[0] == mask.squeeze(0).shape[0]

    #     return img.squeeze(0), mask.squeeze(0), bbox
    
    def __len__(self):
        return self.labels.shape[0]


class BuildDataLoader(LightningDataModule):
    def __init__(self, dataset, batch_size=32):
        super().__init__()

        self.dataset = dataset
        self.batch_size = batch_size

        return

    def setup(self, stage=None):
        test_split = int(0.2 * len(self.dataset))  # 5% of data to be used as validation set
        val_split = int(0.05 * len(self.dataset))
        self.train_data, self.val_data, self.test_data = random_split(self.dataset, [len(self.dataset)-test_split-val_split, val_split, test_split])

        return
        

    def train_dataloader(self):
        
        # Generating train_dataloader
        return DataLoader(self.train_data, batch_size = self.batch_size, collate_fn=collate_fn, shuffle = True)
    
    def val_dataloader(self):
        
        # Generating train_dataloader
        return DataLoader(self.val_data, batch_size = self.batch_size, collate_fn=collate_fn, shuffle = True)
    
    def predict_dataloader(self):
        
        # Generating val_dataloader
        return DataLoader(self.test_data, batch_size = 1, collate_fn=collate_fn, shuffle = False)

# %% [markdown]
# ###BoxHead Utils

# %%
def iou(anchors, gt):               #Dimensions Anchors: (n_proposals,4), gt (ground_truth_boxes, 4)
    #Extracting centers and h w
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
    px1 =  anchors[:,0].reshape(-1,1)                                            #[n_proposals,1]                                        
    py1 =  anchors[: ,1].reshape(-1,1)                                           #[n_proposals,1]
    px2  = anchors[: ,2].reshape(-1,1)                                           #[n_proposals,1]
    py2  = anchors[: ,3].reshape(-1,1)                                           #[n_proposals,1]
    
    
    gx1  = gt[:,0].reshape(-1,1)                                                 #[ground_truth_boxes,1]
    gy1  = gt[:,1].reshape(-1,1)                                                 #[ground_truth_boxes,1]
    gx2  = gt[:,2].reshape(-1,1)                                                 #[ground_truth_boxes,1] 
    gy2  = gt[:,3].reshape(-1,1)                                                 #[ground_truth_boxes,1]
    
    #Box format [x1 y1 x2 y2]
    box1 =  [px1, py1, px2, py2]
    box2 =  [gx1, gy1, gx2, gy2]

    xA = torch.max(box1[0], box2[0].T)                                            #[n_proposals,ground_truth_boxes] 
    yA = torch.max(box1[1], box2[1].T)                                            #[n_proposals,ground_truth_boxes] 
  
    xB = torch.min(box1[2], box2[2].T)                                            #[n_proposals,ground_truth_boxes] 
    yB = torch.min(box1[3], box2[3].T)                                            #[n_proposals,ground_truth_boxes] 
  
    area_intersection = torch.max(xB-xA, torch.zeros(xB.shape, dtype=xB.dtype,device = device)) * torch.max(yB-yA, torch.zeros(yB.shape, dtype=yB.dtype, device = device))
  
    area_union = (box1[2]-box1[0]) * (box1[3]-box1[1]) + ((box2[2]-box2[0]) * (box2[3]-box2[1])).T - area_intersection
  
    iou = torch.div(area_intersection+1,area_union+1)
    return iou   #[n_proposals, ground_truth_boxes]


# This function decodes the output of the box head that are given in the [t_x,t_y,t_w,t_h] format
# into box coordinates where it return the upper left and lower right corner of the bbox
# Input:
#       regressed_boxes_t: (total_proposals,4) ([t_x,t_y,t_w,t_h] format)
#       flatten_proposals: (total_proposals,4) ([x1,y1,x2,y2] format)
# Output:
#       box: (total_proposals,4) ([x1,y1,x2,y2] format)

def output_decodingd(regressed_boxes_t,flatten_proposals, device='cpu'):
	wp = flatten_proposals[:,2] - flatten_proposals[:,0]
	hp = flatten_proposals[:,3] - flatten_proposals[:,1]

	x_p = (flatten_proposals[:,2] + flatten_proposals[:,0])/2
	y_p = (flatten_proposals[:,3] + flatten_proposals[:,1])/2

	box= torch.zeros(regressed_boxes_t.shape, device=device)
	box[:,0] = regressed_boxes_t[:,0]*wp + x_p - torch.exp(regressed_boxes_t[:,2])*wp/2
	box[:,1] = regressed_boxes_t[:,1]*hp + y_p - torch.exp(regressed_boxes_t[:,3])*hp/2
	box[:,2] = regressed_boxes_t[:,0]*wp + x_p + torch.exp(regressed_boxes_t[:,2])*wp/2
	box[:,3] = regressed_boxes_t[:,1]*hp + y_p + torch.exp(regressed_boxes_t[:,3])*hp/2

	return box

# %% [markdown]
# ###Boxhead Definition

# %%
#BoxHead.py

class BoxHead(pl.LightningModule):
    def __init__(self,Classes=3,P=7, eval_ = False):
        super(BoxHead,self).__init__()
        self.C=Classes
        self.P=P
        self.train_losses = []
        self.validation_losses = []
        self.eval_ = eval_
        # TODO initialize BoxHead

        self.intermediate_layer = nn.Sequential(
                                    nn.Linear(in_features=256*self.P*self.P, out_features=1024),
                                    nn.ReLU(),
                                    nn.Linear(in_features=1024, out_features=1024),
                                    nn.ReLU()
                                    )

        self.classifier_head = nn.Sequential(
                                  nn.Linear(in_features=1024, out_features=self.C+1)
                                  )
        
        self.regressor_head = nn.Sequential(
                                  nn.Linear(in_features=1024, out_features=4*(self.C))
            
                                  )
        
        # self.mask_head = nn.Sequential(
        #                           nn.Conv2d(256, 256, kernel_size=3, padding='same'),
        #                           nn.ReLU(),
        #                           nn.Conv2d(256, 256, kernel_size=3, padding='same'),
        #                           nn.ReLU(),
        #                           nn.Conv2d(256, 256, kernel_size=3, padding='same'),
        #                           nn.ReLU(),
        #                           nn.Conv2d(256, 256, kernel_size=3, padding='same'),
        #                           nn.ReLU(),
        #                           nn.ConvTranspose2d(256, 256, kernel_size=2, stride=2),
        #                           nn.ReLU(),
        #                           nn.Conv2d(256, 4, kernel_size=1),
        #                           nn.Sigmoid()
        #                           )
                                  
        
        for layer in self.intermediate_layer:
          self._init_weights(layer)
        for layer in self.classifier_head:
          self._init_weights(layer)
        for layer in self.regressor_head:
          self._init_weights(layer)
        # for layer in self.mask_head:
        #   self._init_weights(layer)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            module.weight.data.normal_(mean=0.0, std=0.01)
            if module.bias is not None:
                module.bias.data.zero_()

    # Forward the pooled feature vectors through the intermediate layer and the classifier, regressor of the box head
    # Input:
    #        feature_vectors: (total_proposals, 256*P*P)
    # Outputs:
    #        class_logits: (total_proposals,(C+1)) (we assume classes are C classes plus background, notice if you want to use
    #                                               CrossEntropyLoss you should not pass the output through softmax here)
    #        box_pred:     (total_proposals,4*C)
    def forward(self, feature_vectors):
      
      X = self.intermediate_layer(feature_vectors)

      class_logits = self.classifier_head(X)

      # if self.eval_:
      softmax = nn.Softmax()
      class_logits = softmax(class_logits)

      box_pred = self.regressor_head(X)

      return class_logits, box_pred

    # def forward_mask(self, x):

    #   x = self.mask_head(x)

    #   return x


    #  This function assigns to each proposal either a ground truth box or the background class (we assume background class is 0)
    #  Input:
    #       proposals: list:len(bz){(per_image_proposals,4)} ([x1,y1,x2,y2] format)
    #       gt_labels: list:len(bz) {(n_obj)}
    #       bbox: list:len(bz){(n_obj, 4)}
    #  Output: (make sure the ordering of the proposals are consistent with MultiScaleRoiAlign)
    #       labels: (total_proposals,1) (the class that the proposal is assigned)
    #       regressor_target: (total_proposals,4) (target encoded in the [t_x,t_y,t_w,t_h] format)
    def create_ground_truth(self,proposals,gt_labels,bboxes):
      labels = []
      regressor_target = []

      for cur_batch, cur_image_proposals_ in enumerate(proposals):
        cur_image_max_iou = 0
        cur_proposal_label = 0
        cur_image_labels = []
        cur_image_regressor_targets = []

        cur_image_proposals = torch.zeros_like(cur_image_proposals_, device = device)
        cur_image_proposals[:,0] = (cur_image_proposals_[:,0] + cur_image_proposals_[:,2]) / 2
        cur_image_proposals[:,1] = (cur_image_proposals_[:,1] + cur_image_proposals_[:,3]) / 2
        cur_image_proposals[:,2] = cur_image_proposals_[:,2] - cur_image_proposals_[:,0] 
        cur_image_proposals[:,3] = cur_image_proposals_[:,3] - cur_image_proposals_[:,1]

        cur_bbox = torch.zeros_like(bboxes[cur_batch], device = device)
        cur_bbox[:,0] = (bboxes[cur_batch][:,0] + bboxes[cur_batch][:,2]) / 2
        cur_bbox[:,1] = (bboxes[cur_batch][:,1] + bboxes[cur_batch][:,3]) / 2
        cur_bbox[:,2] = bboxes[cur_batch][:,2] - bboxes[cur_batch][:,0] 
        cur_bbox[:,3] = bboxes[cur_batch][:,3] - bboxes[cur_batch][:,1]

        for cur_proposal_ind, cur_proposal in enumerate(cur_image_proposals):
          
          replicated_proposal = cur_proposal.repeat((len(cur_bbox), 1))
          cur_IOU = IOU(cur_bbox.to(device), replicated_proposal.to(device)) # send (x,y,w,h)

          max_iou, max_iou_ind = torch.max(cur_IOU, dim = 0)

          if max_iou > 0.5:
            cur_proposal_label = gt_labels[cur_batch][max_iou_ind]
            
            cur_proposal_bbox = cur_bbox[max_iou_ind]
          else:
            cur_proposal_label = 0
            cur_proposal_bbox = torch.tensor([1,2,3,4], device = device) #TODO

          labels.append(cur_proposal_label)

          box = torch.zeros_like(cur_proposal_bbox)

          box[0] = ((cur_proposal_bbox[0]-cur_proposal[0])/cur_proposal[2])
          box[1] = ((cur_proposal_bbox[1]-cur_proposal[1])/cur_proposal[3])
          box[2] = (torch.log(cur_proposal_bbox[2] / cur_proposal[2]))
          box[3] = (torch.log(cur_proposal_bbox[3] / cur_proposal[3]))

          regressor_target.append(box)

      regressor_target = torch.stack(regressor_target)
      return [int(x) for x in labels], regressor_target



    # This function for each proposal finds the appropriate feature map to sample and using RoIAlign it samples
    # a (256,P,P) feature map. This feature map is then flattened into a (256*P*P) vector
    # Input:
    #      fpn_feat_list: list:len(FPN){(bz,256,H_feat,W_feat)}
    #      proposals: list:len(bz){(per_image_proposals,4)} ([x1,y1,x2,y2] format)
    #      P: scalar
    # Output:
    #      feature_vectors: (total_proposals, 256*P*P)  (make sure the ordering of the proposals are the same as the ground truth creation)
    def MultiScaleRoiAlign(self, fpn_feat_list,proposals,P=7):
        #####################################
        # Here you can use torchvision.ops.RoIAlign check the docs
        #####################################

        image_size = (800, 1088) # (h, w)
        feature_vectors = []

        num_proposals = len(proposals)
        for i in range(num_proposals):
            cur_proposal = proposals[i]
            for j in range(cur_proposal.shape[0]):
              width = cur_proposal[j][2] - cur_proposal[j][0]
              height = cur_proposal[j][3] - cur_proposal[j][1]
              K = torch.clip(torch.floor( 4 + torch.log2(torch.sqrt(width*height)/224)),2,5).int()
          
              box = cur_proposal[j].clone()
              scale_x = image_size[1]/fpn_feat_list[K-2].shape[3]
              scale_y = image_size[0]/fpn_feat_list[K-2].shape[2]

              box = box.reshape(1,-1)
              box[:,0] = box[:,0] / scale_x
              box[:,1] = box[:,1] / scale_y 
              box[:,2] = box[:,2] / scale_x
              box[:,3] = box[:,3] / scale_y
            
              feature_map = fpn_feat_list[K-2][i].unsqueeze(0) 
              aligned_box_map  = torchvision.ops.roi_align(feature_map, [box], output_size=P, spatial_scale=1, sampling_ratio=-1)
              aligned_box_map = aligned_box_map.flatten()

              feature_vectors.append(aligned_box_map)
        
        feature_vectors = torch.stack(feature_vectors, dim=0)

        return feature_vectors


    def training_step(self, batch, batch_idx):
      images, labels, masks, bboxes, indices = batch
      # logits, bbox_regs = self.forward(images.to(device))
      # ground_clas, ground_coord = self.create_batch_truth(bboxes, indices, self.image_size)
      masks = list(masks)
      images = images.to(device)
      backout = backbone(images)

      # The RPN implementation takes as first argument the following image list
      im_lis = ImageList(images, [(800, 1088)]*images.shape[0])
      # Then we pass the image list and the backbone output through the rpn
      rpnout = rpn(im_lis, backout)
      proposals=[proposal[0:keep_topK,:] for proposal in rpnout[0]]
      # A list of features produces by the backbone's FPN levels: list:len(FPN){(bz,256,H_feat,W_feat)}
      fpn_feat_list= list(backout.values())

      feature_vectors = self.MultiScaleRoiAlign(fpn_feat_list, proposals)

    #   labels, regressor_targets = model.create_ground_truth(proposals, labels, bboxes)
      # labels, regressor_target = labels[:keep_topK], regressor_target[:keep_topK]
      # print(len(feature))
      # print(feature_vectors.shape)
      class_logits, box_preds = self.forward(feature_vectors)
      # print(box_preds.shape)

      '''
      proposals: x1
      '''

      labels = torch.tensor(labels)
      loss, loss_c, loss_r = self.compute_loss(class_logits, box_preds, labels, regressor_targets,l=10,effective_batch=150)

      boxes = []
      # scores = []
      # labels = []
      for i, proposal in enumerate(proposals):
        class_logit = class_logits[i*keep_topK: i*keep_topK + keep_topK]
        box_pred = box_preds[i*keep_topK: i*keep_topK + keep_topK]
        score, box, _ = self.postprocess_detections(images.squeeze(0), class_logits = class_logit, box_regression = box_pred, proposals = proposal, conf_thresh = 0.5, keep_num_preNMS=500, keep_num_postNMS=100, plot_=False)
        # print(box)
        boxes.append(box)

      # print(boxes[0].shape)
      # print(boxes)
      if boxes[0] is not None:
        feature_vectors_2 = self.MaskMultiScaleRoiAlign(fpn_feat_list, boxes)

        # # mask_pred =  self.forward_mask(feature_vectors_2.squeeze(0))
        # if mask_pred.shape[0] < masks[0].shape[0]:
        #   masks[0] = masks[0][:mask_pred.shape[0]]
        # print(mask_pred.shape)
        loss_m = self.loss_bce(mask_pred, masks[0])
        loss = loss + loss_m

        self.log("train_class_loss", loss_c, prog_bar=True)
        self.log("train_regr_loss", loss_r, prog_bar=True)
        self.log("train_mask_loss", loss_m, prog_bar=True)
        self.log("train_loss", loss, prog_bar=True)
        print("train_loss", loss)
        print("train_mask_loss", loss_m)
        return {"loss": loss, "loss_c": loss_c, "loss_r": loss_r, "loss_m": loss_m}
    
    
    def training_epoch_end(self, outputs):
      self.train_losses.append((torch.tensor([output["loss"] for output in outputs]).mean().item(),\
                                torch.tensor([output["loss_c"] for output in outputs]).mean().item(), \
                                torch.tensor([output["loss_r"] for output in outputs]).mean().item(), \
                                torch.tensor([output["loss_m"] for output in outputs]).mean().item()))

    def validation_step(self, batch, batch_idx):
      images, labels, masks, bboxes, indices = batch
      
      images = images.to(device)
      backout = backbone(images)

      # The RPN implementation takes as first argument the following image list
      im_lis = ImageList(images, [(800, 1088)]*images.shape[0])
      # Then we pass the image list and the backbone output through the rpn
      rpnout = rpn(im_lis, backout)
      proposals=[proposal[0:keep_topK,:] for proposal in rpnout[0]]
      # A list of features produces by the backbone's FPN levels: list:len(FPN){(bz,256,H_feat,W_feat)}
      fpn_feat_list= list(backout.values())

      feature_vectors = self.MultiScaleRoiAlign(fpn_feat_list, proposals)

    #   labels, regressor_targets = model.create_ground_truth(proposals, labels, bboxes)
      # labels, regressor_target = labels[:keep_topK], regressor_target[:keep_topK]
      class_logits, box_preds = self.forward(feature_vectors)

      '''
      proposals: x1
      '''

      labels = torch.tensor(labels)
      loss, loss_c, loss_r = self.compute_loss(class_logits, box_preds, labels, regressor_targets,l=10,effective_batch=150)

      boxes = []
      # scores = []
      # labels = []
      for i, proposal in enumerate(proposals):
        class_logit = class_logits[i*keep_topK: i*keep_topK + keep_topK]
        box_pred = box_preds[i*keep_topK: i*keep_topK + keep_topK]
        score, box, _ = self.postprocess_detections(images.squeeze(0), class_logits = class_logit, box_regression = box_pred, proposals = proposal, conf_thresh = 0.8, keep_num_preNMS=500, keep_num_postNMS=100, plot_=False)
        
        boxes.append(box)

      if boxes[0] is not None:
          feature_vectors_2 = self.MaskMultiScaleRoiAlign(fpn_feat_list, boxes)

          mask_pred =  self.forward_mask(feature_vectors_2)
          if mask_pred.shape[0] < masks[0].shape[0]:
            masks[0] = masks[0][:mask_pred.shape[0]]
          loss_m = self.loss_bce(mask_pred, masks[0])
          
          loss = loss + loss_m

          self.log("train_class_loss", loss_c, prog_bar=True)
          self.log("train_regr_loss", loss_r, prog_bar=True)
          self.log("train_mask_loss", loss_m, prog_bar=True)
          self.log("train_loss", loss, prog_bar=True)

          return {"loss": loss, "loss_c": loss_c, "loss_r": loss_r, "loss_m": loss_m}
    
    def validation_epoch_end(self, outputs):
      self.validation_losses.append((torch.tensor([output["loss"] for output in outputs]).mean().item(),\
                                torch.tensor([output["loss_c"] for output in outputs]).mean().item(), \
                                torch.tensor([output["loss_r"] for output in outputs]).mean().item(), \
                                torch.tensor([output["loss_m"] for output in outputs]).mean().item()))
    
    def configure_optimizers(self):
      optimizer = torch.optim.SGD(self.parameters(), lr=0.001, weight_decay = 5e-4)
      scheduler = {"scheduler": torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[20, 30], gamma=0.1)}
      return {"optimizer": optimizer, 'lr_scheduler': scheduler}


    # This function does the post processing for the results of the Box Head for a batch of images
    # Use the proposals to distinguish the outputs from each image
    # Input:
    #       class_logits: (total_proposals,(C+1))
    #       box_regression: (total_proposal,4*C)           ([t_x,t_y,t_w,t_h] format)
    #       proposals: list:len(bz)(per_image_proposals,4) (the proposals are produced from RPN [x1,y1,x2,y2] format)
    #       conf_thresh: scalar
    #       keep_num_preNMS: scalar (number of boxes to keep pre NMS)
    #       keep_num_postNMS: scalar (number of boxes to keep post NMS)
    # Output:
    #       boxes: list:len(bz){(post_NMS_boxes_per_image,4)}  ([x1,y1,x2,y2] format)
    #       scores: list:len(bz){(post_NMS_boxes_per_image)}   ( the score for the top class for the regressed box)
    #       labels: list:len(bz){(post_NMS_boxes_per_image)}   (top class of each regressed box)
    # def postprocess_detections(self, decoded_image, class_logits, box_regression, proposals, conf_thresh=0.5, keep_num_preNMS=500, keep_num_postNMS=50, plot_ = True):

    #   class_scores, class_labels = torch.max(class_logits, dim =1)
    #   valid_indices = class_labels > 0
    #   # print(proposals.shape)
    #   # print(valid_indices.shape)
    #   proposals = proposals[valid_indices]
    #   box_regression = box_regression[valid_indices]
    #   class_labels = class_labels[valid_indices]
    #   class_scores = class_scores[valid_indices]
      

    #   boxes = torch.zeros((len(class_labels), 4))
    #   for i in range(len(class_labels)):
    #     boxes[i,:] = box_regression[i, (class_labels[i]-1)*4:class_labels[i]*4 ]
    #   boxes = flattened_output_decoding(boxes, proposals)

    #   boxes[boxes[:,2] > 1088, 2] = 1088
    #   boxes[boxes[:,3] > 800, 3] = 800
    #   boxes[boxes[:,0] < 0, 0] = 0
    #   boxes[boxes[:,1] < 0, 1] = 0


    #   sorted_scores, sorted_indices = torch.sort(class_scores, descending = True) 

    #   keep_num_preNMS = min(keep_num_preNMS, len(sorted_scores))
    #   pre_nms_indices = sorted_indices[0:keep_num_preNMS]
    #   pre_nms_scores = sorted_scores[0:keep_num_preNMS] 
    #   boxes = boxes[pre_nms_indices,:]
    #   class_labels = class_labels[pre_nms_indices]

      
    #   boxes = boxes.detach().numpy()

    #   if plot_:
    #     label_to_color = {}
    #     label_to_color[1] = 'r'
    #     label_to_color[2] = 'g'
    #     label_to_color[3] = 'b'
    #     gt_label_color = 'c'

    #     label_to_class = {1: 'Vehicle', 2: 'Person', 3: 'Animal'}
    #     label_to_color_name = {1: 'Red', 2: 'Green', 3: 'Blue'}
    #     if keep_num_postNMS > 0:
    #       print('------------------- Predicted Boxes pre-NMS ----------------')
          
    #     figure, axis = plt.subplots(1, 3)
    #     figure.set_size_inches(18.5, 10.5)

    #     axis[0].imshow(decoded_image.permute(1, 2, 0))
    #     axis[0].set_title('Cyan = Ground Truth Box, ' + label_to_color_name[1] + ' = ' +label_to_class[1] + ' box.') 
    #     axis[1].imshow(decoded_image.permute(1, 2, 0))
    #     axis[1].set_title('Cyan = Ground Truth Box, ' + label_to_color_name[2] + ' = ' +label_to_class[2] + ' box.') 
    #     axis[2].imshow(decoded_image.permute(1, 2, 0))
    #     axis[2].set_title('Cyan = Ground Truth Box, ' + label_to_color_name[3] + ' = ' +label_to_class[3] + ' box.') 
        
    #     proposals = boxes
    #     for i, label in enumerate(class_labels):
            
    #         # proposal box
    #         proposal = proposals[i, :]
    #         box = Rectangle((proposal[0], proposal[1]), proposal[2] - proposal[0], proposal[3] - proposal[1],  linewidth=1, edgecolor=label_to_color[label.item()], facecolor='none')
    #         axis[int(label) - 1].add_patch(box)

    #     plt.show()

    #   if keep_num_postNMS > 0:
    #     if pre_nms_scores.shape[0] == 0:
    #       return None, None, None
    #     # print('------------------- Predicted Boxes post-NMS ----------------')
    #     # post_nms_score, post_nms_boxes, post_nms_labels  = self.NMS(pre_nms_scores, torch.tensor(boxes, device = device), torch.tensor(class_labels, device= device), conf_thresh)
    #     post_nms_score, post_nms_boxes, post_nms_labels  = self.py_soft_nms(torch.cat((torch.tensor(boxes, device = device), pre_nms_scores), dim = 1), iou_thr = conf_thresh)
    #     sorted_post_nms_scores, sorted_post_nms_indices = torch.sort(post_nms_score, descending = True) 

    #     keep_num_postNMS = min(keep_num_postNMS, len(post_nms_score))
  
    #     post_nms_indices = sorted_post_nms_indices[0:keep_num_postNMS]
    #     post_nms_scores = sorted_post_nms_scores[0:keep_num_postNMS]
        
    #     post_nms_boxes = post_nms_boxes[post_nms_indices,:]
    #     post_nms_labels = post_nms_labels[post_nms_indices]
        
    #     if plot_:
    #       boxes = post_nms_boxes.cpu().numpy()
          
    #       figure, axis = plt.subplots(1, 3)
    #       figure.set_size_inches(18.5, 10.5)

    #       axis[0].imshow(decoded_image.permute(1, 2, 0))
    #       axis[0].set_title('Cyan = Ground Truth Box, ' + label_to_color_name[1] + ' = ' +label_to_class[1] + ' box.') 
    #       axis[1].imshow(decoded_image.permute(1, 2, 0))
    #       axis[1].set_title('Cyan = Ground Truth Box, ' + label_to_color_name[2] + ' = ' +label_to_class[2] + ' box.') 
    #       axis[2].imshow(decoded_image.permute(1, 2, 0))
    #       axis[2].set_title('Cyan = Ground Truth Box, ' + label_to_color_name[3] + ' = ' +label_to_class[3] + ' box.') 
          
    #       proposals = boxes
     
    #       for i, label in enumerate(post_nms_labels):
 
    #         if label != 0:
              
    #           # proposal box
    #           proposal = proposals[i, :]
    
    #           box = Rectangle((proposal[0], proposal[1]), proposal[2] - proposal[0], proposal[3] - proposal[1],  linewidth=1, edgecolor=label_to_color[label.item()], facecolor='none')
    #           axis[int(label) - 1].add_patch(box)

    #       plt.show()
    #       print('\n')
     

    #     return post_nms_scores, post_nms_boxes, post_nms_labels
    #   else:
    #     return 0,0,0


    def postprocess_detections(self, class_logits, box_regression, proposals, conf_thresh=0.0, keep_num_preNMS=500, keep_num_postNMS=50):
        class_logits = class_logits.cpu()
        box_regression = box_regression.cpu()
      
        class_scores, class_idx = torch.max(class_logits, dim =1)

        background = class_idx==0
        class_scores[background] = 0

        class_idx_cp = class_idx.clone() - 1
        class_idx_cp[class_idx == 0] = 0

        # print("class scores", class_scores)
        # print("class scores", class_idx)

        cols_to_idx           =     np.linspace(4*class_idx_cp,4*class_idx_cp+3,4).T
        rows                  =     np.arange(box_regression.shape[0]).reshape(-1,1)

        boxes_regr        = box_regression[rows, cols_to_idx]

        boxes  = []
        scores = []
        labels = []
        iou_thresh = 0.5

        j=0
        for i in range(len(proposals)):
          proposals_per_image = proposals[i].shape[0]
          unsorted_boxes_coded = boxes_regr[j:j+proposals_per_image]
          unsorted_boxes = output_decodingd(unsorted_boxes_coded,proposals[i].cpu(), device='cpu')
          
          unsorted_scores = class_scores[j:j+proposals_per_image]
          unsorted_labels = class_idx[j:j+proposals_per_image]

          #Removing out of bound boxes
          out_of_range = torch.logical_or(unsorted_boxes[:,0]<0 , unsorted_boxes[:,1]<0)
          out_of_range = torch.logical_or(out_of_range,torch.logical_or(unsorted_boxes[:,2]>1088, unsorted_boxes[:,3]>800))
          unsorted_scores[out_of_range] = 0

          sorted_scores, sorted_score_idx = torch.sort(unsorted_scores, descending = True)
          
          # idx = sorted_scores>0
          # sorted_scores = sorted_scores[idx]
          # sorted_score_idx = sorted_score_idx[idx]
          # print('sorted_scores', sorted_scores.shape)
          if (sorted_scores.shape[0]>keep_num_preNMS):
              sorted_scores = sorted_scores[:keep_num_preNMS]
              sorted_score_idx = sorted_score_idx[:keep_num_preNMS]
          
          pre_nms_scores = sorted_scores
          pre_nms_boxes = unsorted_boxes[sorted_score_idx]
          pre_nms_labels = unsorted_labels[sorted_score_idx]

          ious = iou(pre_nms_boxes.to(self.device), pre_nms_boxes.to(self.device)).triu(diagonal = 1)
          
          # print("ious", ious)
          # print("ious shape", ious.shape)

          post_nms_idx    = (ious>iou_thresh).sum(dim=0) == 0
          # print("nms", post_nms_idx)
          post_nms_idx = post_nms_idx.cpu()
          post_nms_scores = pre_nms_scores[post_nms_idx]
          post_nms_boxes  = pre_nms_boxes[post_nms_idx]
          post_nms_labels = pre_nms_labels[post_nms_idx]

          if (post_nms_scores.shape[0]>keep_num_postNMS):
              boxes.append(post_nms_boxes[:keep_num_postNMS])
              scores.append(post_nms_scores[:keep_num_postNMS])
              labels.append(post_nms_labels[:keep_num_postNMS])
          else:
              boxes.append(post_nms_boxes)
              scores.append(post_nms_scores)
              labels.append(post_nms_labels)

          j= j+proposals_per_image

        # print("Len boxes", len(boxes))
        # print("Len Scores", len(scores))
        # print("Len Labels", len(labels))

        return boxes, scores, labels

    # Compute the loss of the classifier
    # Input:
    #      p_out:     (positives_on_mini_batch)  (output of the classifier for sampled anchors with positive gt labels)
    #      n_out:     (negatives_on_mini_batch) (output of the classifier for sampled anchors with negative gt labels
    def loss_class(self,p_out,n_out,p_label, n_label):


        # TODO compute classifier's loss
        
        target = torch.cat((p_label,n_label), 0).to(device)
        output = torch.cat((p_out, n_out), 0)
      

        loss_classifier = torch.nn.CrossEntropyLoss()
        loss = loss_classifier(output, target)

        return loss

    # Compute the loss of the regressor
    # Input:
    #       pos_target_coord: (positive_on_mini_batch,4) (ground truth of the regressor for sampled anchors with positive gt labels)
    #       pos_out_r: (positive_on_mini_batch,4)        (output of the regressor for sampled anchors with positive gt labels)
    def loss_reg(self,pos_target_coord,pos_out_r):
            #torch.nn.SmoothL1Loss()
            # TODO compute regressor's loss
            # print(pos_out_r.shape)
            loss_regressor = torch.nn.SmoothL1Loss(reduction = 'sum')
            loss = loss_regressor(pos_out_r.squeeze(1),pos_target_coord)

            return loss

    def loss_bce(self, mask_pred, masks):
        # print(mask_pred)
        # print(masks)
        # print(mask_pred.shape)
        # print(masks.shape)
        l = nn.BCELoss()
        loss = l(mask_pred, masks)
        return loss


    # Compute the total loss of the classifier and the regressor
    # Input:
    #      class_logits: (total_proposals,(C+1)) (as outputed from forward, not passed from softmax so we can use CrossEntropyLoss)
    #      box_preds: (total_proposals,4*C)      (as outputed from forward)
    #      labels: (total_proposals,1)
    #      regression_targets: (total_proposals,4)
    #      l: scalar (weighting of the two losses)
    #      effective_batch: scalar
    # Outpus:
    #      loss: scalar
    #      loss_class: scalar
    #      loss_regr: scalar
    def compute_loss(self,class_logits, box_preds, labels, regression_targets,l=1,effective_batch=150):
    
        

        pos_n = (labels != 0).sum().item()
        neg_n = labels.shape[0] - pos_n


        if pos_n < (3*effective_batch/4):
          pos_idx = np.random.choice(pos_n, pos_n, replace = False)
          neg_idx = np.random.choice(neg_n, min(effective_batch - pos_n, neg_n), replace = False) 
          if(effective_batch - pos_n > neg_n):
            print('!!!ALERT!!! \n effective_batch - pos_n:', effective_batch - pos_n, ' neg_n:', neg_n, ' labels.shape[0]:', labels.shape[0])
        else:
          pos_idx = np.random.choice(pos_n, (3*effective_batch)//4, replace = False)
          neg_idx = np.random.choice(neg_n, min(effective_batch//4, neg_n), replace = False)
          if(effective_batch//4 > neg_n):
            print('!!!ALERT!!! \n effective_batch//4:', effective_batch//4, ' neg_n:', neg_n, ' labels.shape[0]:', labels.shape[0])

        p_out = class_logits[(labels != 0), :][pos_idx, :]
    
        n_out = class_logits[(labels == 0), :][neg_idx, :]
        p_label = labels[ (labels != 0)][pos_idx]
        n_label = labels[ (labels == 0)][neg_idx]
        loss_c = self.loss_class(p_out, n_out, p_label, n_label)


        regr_pos = box_preds[(labels != 0) ,:][pos_idx,:]
        rows = np.arange(regr_pos.shape[0]).reshape(-1,1)

        box_pred = regr_pos[rows,:4]

        targ_regr_pos = regression_targets[(labels != 0) ,:][pos_idx,:]
        loss_r = self.loss_reg(targ_regr_pos, box_pred.squeeze(0))/effective_batch

        loss = loss_c + l*loss_r
        
        return loss, loss_c, loss_r




    def NMS(self,clas,prebox, labels, thresh):
    ##################################
    # TODO perform NSM
    ##################################
    
      method= 'gauss'
      n = len(clas)
      ious_thresh = 0.5

      # x1 = prebox[:,0] - (prebox[:,2]/2).reshape(-1,1)
      # y1 = prebox[:,1] - (prebox[:,3]/2).reshape(-1,1)
      # x2 = prebox[:,0] + (prebox[:,2]/2).reshape(-1,1)
      # y2 = prebox[:,1] + (prebox[:,3]/2).reshape(-1,1)

      x1 = prebox[:,0]
      y1 = prebox[:,1]
      x2 = prebox[:,2]
      y2 = prebox[:,3]

      x1_ = torch.max(x1,x1.T)
      y1_ = torch.max(y1,y1.T)
      x2_ = torch.min(x2,x2.T)
      y2_ = torch.min(y2,y2.T)

      intersection = (x2_ - x1_ + 1).clamp(0) * (y2_ - y1_ + 1).clamp(0)

      union = (x2 - x1 + 1) * (y2 - y1 + 1) + (x2.T - x1.T + 1) * (y2.T - y1.T + 1) - intersection

      ious = (intersection / union).triu(diagonal=1)

      post_nms_idx    = (ious>iou_thresh).sum(dim=0) == 0
          # print("nms", post_nms_idx)
      post_nms_scores = pre_nms_scores[post_nms_idx]
      post_nms_boxes  = pre_nms_boxes[post_nms_idx]
      post_nms_labels = pre_nms_labels[post_nms_idx]

      if (post_nms_scores.shape[0]>keep_num_postNMS):
          boxes.append(post_nms_boxes[:keep_num_postNMS])
          scores.append(post_nms_scores[:keep_num_postNMS])
          labels.append(post_nms_labels[:keep_num_postNMS])
      else:
          boxes.append(post_nms_boxes)
          scores.append(post_nms_scores)
          labels.append(post_nms_labels)


      return scores, boxes, labels


    def py_soft_nms(dets, method=None, iou_thr=0.5, sigma=0.5, score_thr=0.001):
        """Pure python implementation of soft NMS as described in the paper
        `Improving Object Detection With One Line of Code`_.
        Args:
            dets (numpy.array): Detection results with shape `(num, 5)`,
                data in second dimension are [x1, y1, x2, y2, score] respectively.
            method (str): Rescore method. Only can be `linear`, `gaussian`
                or 'greedy'.
            iou_thr (float): IOU threshold. Only work when method is `linear`
                or 'greedy'.
            sigma (float): Gaussian function parameter. Only work when method
                is `gaussian`.
            score_thr (float): Boxes that score less than the.
        Returns:
            numpy.array: Retained boxes.
        .. _`Improving Object Detection With One Line of Code`:
            https://arxiv.org/abs/1704.04503
        """
        if method not in ('linear', 'gaussian', 'greedy'):
            raise ValueError('method must be linear, gaussian or greedy')

        x1 = dets[:, 0]
        y1 = dets[:, 1]
        x2 = dets[:, 2]
        y2 = dets[:, 3]

        areas = (x2 - x1 + 1) * (y2 - y1 + 1)
        # expand dets with areas, and the second dimension is
        # x1, y1, x2, y2, score, area
        dets = torch.cat((dets, areas[:, None]), dim=1)

        retained_box = []
        while dets.size > 0:
            max_idx = torch.argmax(dets[:, 4], axis=0)
            dets[[0, max_idx], :] = dets[[max_idx, 0], :]
            retained_box.append(dets[0, :-1])

            xx1 = torch.maximum(dets[0, 0], dets[1:, 0])
            yy1 = torch.maximum(dets[0, 1], dets[1:, 1])
            xx2 = torch.minimum(dets[0, 2], dets[1:, 2])
            yy2 = torch.minimum(dets[0, 3], dets[1:, 3])

            w = torch.maximum(xx2 - xx1 + 1, 0.0)
            h = torch.maximum(yy2 - yy1 + 1, 0.0)
            inter = w * h
            iou = inter / (dets[0, 5] + dets[1:, 5] - inter)

            if method == 'linear':
                weight = torch.ones_like(iou)
                weight[iou > iou_thr] -= iou[iou > iou_thr]
            elif method == 'gaussian':
                weight = np.exp(-(iou * iou) / sigma)
            else:  # traditional nms
                weight = np.ones_like(iou)
                weight[iou > iou_thr] = 0

            dets[1:, 4] *= weight
            retained_idx = torch.where(dets[1:, 4] >= score_thr)[0]
            dets = dets[retained_idx + 1, :]

        return torch.vstack(retained_box)

    def MaskMultiScaleRoiAlign(self, fpn_feat_list,proposals,P=14):

          image_size = (800, 1088) # (h, w)
          feature_vectors = []
          # print('proposals:', proposals)

          num_proposals = len(proposals)
          # print(num_proposals)
          for i in range(num_proposals):
              cur_proposal = proposals[i]
              feature_vectors_ = []
              for j in range(cur_proposal.shape[0]):
                width = cur_proposal[j][2] - cur_proposal[j][0]
                height = cur_proposal[j][3] - cur_proposal[j][1]
                K = torch.clip(torch.floor( 4 + torch.log2(torch.sqrt(width*height)/224)),2,5).int()
            
                box = cur_proposal[j].clone()
                scale_x = image_size[1]/fpn_feat_list[K-2].shape[3]
                scale_y = image_size[0]/fpn_feat_list[K-2].shape[2]

                box = box.reshape(1,-1)
                box[:,0] = box[:,0] / scale_x
                box[:,1] = box[:,1] / scale_y 
                box[:,2] = box[:,2] / scale_x
                box[:,3] = box[:,3] / scale_y
              
                feature_map = fpn_feat_list[K-2][i].unsqueeze(0) 
                aligned_box_map  = torchvision.ops.roi_align(feature_map, [box], output_size=P, spatial_scale=1, sampling_ratio=-1)
                # aligned_box_map = aligned_box_map.flatten()
                # print(aligned_box_map.shape)
                feature_vectors_.append(aligned_box_map)
          
              feature_vectors_ = torch.cat(feature_vectors_, dim=0)
              # print('feature_vectors_.shape: ',feature_vectors_.shape)
              # print(feature_vectors_.unsqueeze(0).shape)
              feature_vectors.append(feature_vectors_.unsqueeze(0))

          feature_vectors = torch.cat(feature_vectors, dim=0)
          # print('feature_vectors.shape:', feature_vectors.shape)
          return feature_vectors

    def postprocess_detections_mask(self, decoded_image, class_logits, box_regression, proposals, conf_thresh=0.8, keep_num_preNMS=100, keep_num_postNMS=50, plot_ = False):

      

      class_scores, class_labels = torch.max(class_logits, dim =1)

      valid_indices = class_labels > 0

      proposals = proposals[valid_indices]
      box_regression = box_regression[valid_indices]
      class_labels = class_labels[valid_indices]
      class_scores = class_scores[valid_indices]
      

      boxes = torch.zeros((len(class_labels), 4))
      for i in range(len(class_labels)):
        boxes[i,:] = box_regression[i, (class_labels[i]-1)*4:class_labels[i]*4 ]
      boxes = flattened_output_decoding(boxes, proposals)

      boxes[boxes[:,2] > 1088, 2] = 1088
      boxes[boxes[:,3] > 800, 3] = 800
      boxes[boxes[:,0] < 0, 0] = 0
      boxes[boxes[:,1] < 0, 1] = 0


      # print(class_scores.shape)
      sorted_scores, sorted_indices = torch.sort(class_scores, descending = True) 

      keep_num_preNMS = min(keep_num_preNMS, len(sorted_scores))
      pre_nms_indices = sorted_indices[0:keep_num_preNMS]
      pre_nms_scores = sorted_scores[0:keep_num_preNMS] 
      boxes = boxes[pre_nms_indices,:]
      class_labels = class_labels[pre_nms_indices]
      # print(boxes.shape)
      # print(pre_nms_scores.shape)
      boxes = boxes.to(device)

      inds = torchvision.ops.nms(boxes, pre_nms_scores, 0.5)

      boxes = boxes[inds]
      # print(boxes.shape)
      
      # boxes = boxes.detach().numpy()
      return boxes, pre_nms_scores, class_labels

# %% [markdown]
# ###Box Head Training

# %%
model = BoxHead(Classes=3,P=7)
model.to(device)
keep_topK=500
trainer = pl.Trainer(max_epochs=num_epochs, gpus=1, num_sanity_val_steps=0)
trainer.fit(model, COCODataLoader)
torch.save(model.state_dict(), 'boxhead_new.pth')
np.save('train_losses.npy', model.train_losses)
np.save('val_losses.npy', model.validation_losses)

# %%
# !cp -r boxhead_new.pth /content/drive/MyDrive/Mask/

# %% [markdown]
# ###Caching rpn and boxhead

# %%
# Put the path were you save the given pretrained model
pretrained_path='/content/drive/MyDrive/Pretrained_Models/checkpoint680.pth'
# pretrained_path='/content/checkpoint680.pth'
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
backbone, rpn = pretrained_models_680(pretrained_path)
backbone = backbone.to(device).eval()
rpn = rpn.to(device).eval()

# we will need the ImageList from torchvision
from torchvision.models.detection.image_list import ImageList


# imgs_path = '/content/drive/MyDrive/Mask/COCOdataset2017/NewData5/finalTrainImages.h5'
# masks_path = '/content/drive/MyDrive/Mask/COCOdataset2017/NewData5/finalTrainMasks.h5'
# labels_path = '/content/drive/MyDrive/Mask/COCOdataset2017/NewData5/finalTrainLabels.npy'
# bboxes_path = '/content/drive/MyDrive/Mask/COCOdataset2017/NewData5/finalTrainBboxes.npy'

imgs_path = '/content/drive/MyDrive/Mask/data_rusk/hw3_mycocodata_img_comp_zlib.h5'
masks_path = '/content/drive/MyDrive/Mask/data_rusk/hw3_mycocodata_mask_comp_zlib.h5'
labels_path = '/content/drive/MyDrive/Mask/data_rusk/hw3_mycocodata_labels_comp_zlib.npy'
bboxes_path = '/content/drive/MyDrive/Mask/data_rusk/hw3_mycocodata_bboxes_comp_zlib.npy'

paths = [imgs_path, masks_path, labels_path, bboxes_path]

batch_size = 1
num_epochs = 36

image_transform = transforms.Compose([
                            transforms.ToTensor(),
                            transforms.Resize((800, 1066)),
                            transforms.Normalize(mean=(0.485,0.456,0.406), std=(0.229,0.224,0.225)),
                            transforms.Pad([11,0])
                            ])

mask_transform = transforms.Compose([       
                          transforms.Resize((800, 1066)),
                          transforms.Pad([11,0])
                          ])

COCOdata = BuildDataset(paths, image_transform, mask_transform)

COCODataLoader = BuildDataLoader(COCOdata, batch_size=batch_size)

COCODataLoader.setup()
test_loader = COCODataLoader.predict_dataloader() 
train_loader = COCODataLoader.train_dataloader()
val_loader = COCODataLoader.val_dataloader()
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# <ipython-input-5-c0c3fe80d97f>:23: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   label_based_masks = np.array(label_based_masks)

# %%
boxhead_weights_path = '/content/boxhead.pth'

boxhead = BoxHead(eval_ = True)
boxhead.to(device)
box_weights = torch.load(boxhead_weights_path)
boxhead.load_state_dict(box_weights)
boxhead.eval()
# Out:
# BoxHead(
#   (intermediate_layer): Sequential(
#     (0): Linear(in_features=12544, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=1024, bias=True)
#     (3): ReLU()
#   )
#   (classifier_head): Sequential(
#     (0): Linear(in_features=1024, out_features=4, bias=True)
#   )
#   (regressor_head): Sequential(
#     (0): Linear(in_features=1024, out_features=12, bias=True)
#   )
# )

# %%
keep_topK = 500
confidence_scores_path = '/content/scores/'
box_preds_path = '/content/boxes/'
proposal_path = '/content/proposals/'
for j, batch in enumerate(test_loader):

  images, labels, masks, bboxes, indices = batch
  # print(images.shape)
  images = images.to(device)
  backout = backbone(images)

  # The RPN implementation takes as first argument the following image list
  im_lis = ImageList(images, [(800, 1088)]*images.shape[0])
  # Then we pass the image list and the backbone output through the rpn
  rpnout = rpn(im_lis, backout)
  proposals=[proposal[0:keep_topK,:] for proposal in rpnout[0]]

  # print(len(proposals))
  # print(proposals[0])
  # A list of features produces by the backbone's FPN levels: list:len(FPN){(bz,256,H_feat,W_feat)}
  fpn_feat_list= list(backout.values())

  feature_vectors = boxhead.MultiScaleRoiAlign(fpn_feat_list, proposals)

  labels, regressor_targets = boxhead.create_ground_truth(proposals, labels, bboxes)
  
  class_logits, box_preds = boxhead.forward(feature_vectors)
  # print(class_logits.shape)

  for i, idx in enumerate(indices):
    torch.save(class_logits[i*500:(i+1)*500, :], confidence_scores_path + 'cls_logit_' + str(idx) + '.pt')
    torch.save(box_preds[i*500:(i+1)*500, :], box_preds_path + 'box_pred_' + str(idx) + '.pt')
    torch.save(proposals[i], proposal_path + 'prop_pred_' + str(idx) + '.pt')

# %% [markdown]
# ### MaskHead Utils

# %%
# !unzip /content/scores.zip
# !unzip /content/boxes.zip
# !unzip /content/proposals.zip
# Out:
# Archive:  /content/scores.zip
#    creating: content/scores/
#   inflating: content/scores/box_pred_1697.pt
#   inflating: content/scores/box_pred_40.pt
#   inflating: content/scores/box_pred_2739.pt
#   inflating: content/scores/box_pred_1197.pt
#   inflating: content/scores/box_pred_2946.pt
#   inflating: content/scores/box_pred_731.pt
#   inflating: content/scores/box_pred_360.pt
#   inflating: content/scores/box_pred_2816.pt
#   inflating: content/scores/box_pred_2149.pt
#   inflating: content/scores/box_pred_2547.pt
#   inflating: content/scores/box_pred_1950.pt
#   inflating: content/scores/box_pred_2831.pt
#   inflating: content/scores/box_pred_1057.pt
#   inflating: content/scores/box_pred_1363.pt
#   inflating: content/scores/box_pred_2788.pt
#   inflating: content/scores/box_pred_3006.pt
#   inflating: content/scores/box_pred_2423.pt
#   inflating: content/scores/box_pred_113.pt
#   inflating: content/scores/box_pred_1498.pt
#   inflating: content/scores/box_pred_1853.pt
#   inflating: content/scores/box_pred_1156.pt
#   inflating: content/scores/box_pred_2755.pt
#   inflating: content/scores/box_pred_2222.pt
#   inflating: content/scores/box_pred_2614.pt
#   inflating: content/scores/box_pred_663.pt
#   inflating: content/scores/box_pred_2914.pt
#   inflating: content/scores/box_pred_1153.pt
#   inflating: content/scores/box_pred_581.pt
#   inflating: content/scores/box_pred_305.pt
#   inflating: content/scores/box_pred_940.pt
#   inflating: content/scores/box_pred_2257.pt
#   inflating: content/scores/box_pred_2706.pt
#   inflating: content/scores/box_pred_353.pt
#   inflating: content/scores/box_pred_1420.pt
#   inflating: content/scores/box_pred_874.pt
#   inflating: content/scores/box_pred_112.pt
#   inflating: content/scores/box_pred_430.pt
#   inflating: content/scores/box_pred_1473.pt
#   inflating: content/scores/box_pred_2621.pt
#   inflating: content/scores/box_pred_2813.pt
#   inflating: content/scores/box_pred_875.pt
#   inflating: content/scores/box_pred_227.pt
#   inflating: content/scores/box_pred_2545.pt
#   inflating: content/scores/box_pred_1763.pt
#   inflating: content/scores/box_pred_203.pt
#   inflating: content/scores/box_pred_893.pt
#   inflating: content/scores/box_pred_710.pt
#   inflating: content/scores/box_pred_3046.pt
#   inflating: content/scores/box_pred_921.pt
#   inflating: content/scores/box_pred_2184.pt
#   inflating: content/scores/box_pred_1771.pt
#   inflating: content/scores/box_pred_2268.pt
#   inflating: content/scores/box_pred_3244.pt
#   inflating: content/scores/box_pred_188.pt
#   inflating: content/scores/box_pred_2795.pt
#   inflating: content/scores/box_pred_2965.pt
#   inflating: content/scores/box_pred_2137.pt
#   inflating: content/scores/box_pred_2893.pt
#   inflating: content/scores/box_pred_2569.pt
#   inflating: content/scores/box_pred_2427.pt
#   inflating: content/scores/box_pred_2367.pt
#   inflating: content/scores/box_pred_833.pt
#   inflating: content/scores/box_pred_528.pt
#   inflating: content/scores/box_pred_189.pt
#   inflating: content/scores/box_pred_645.pt
#   inflating: content/scores/box_pred_1109.pt
#   inflating: content/scores/box_pred_1042.pt
#   inflating: content/scores/box_pred_887.pt
#   inflating: content/scores/box_pred_2799.pt
#   inflating: content/scores/box_pred_3041.pt
#   inflating: content/scores/box_pred_2705.pt
#   inflating: content/scores/box_pred_3107.pt
#   inflating: content/scores/box_pred_1112.pt
#   inflating: content/scores/box_pred_526.pt
#   inflating: content/scores/box_pred_802.pt
#   inflating: content/scores/box_pred_3211.pt
#   inflating: content/scores/box_pred_3123.pt
#   inflating: content/scores/box_pred_987.pt
#   inflating: content/scores/box_pred_1044.pt
#   inflating: content/scores/box_pred_216.pt
#   inflating: content/scores/box_pred_1607.pt
#   inflating: content/scores/box_pred_2027.pt
#   inflating: content/scores/box_pred_2890.pt
#   inflating: content/scores/box_pred_3003.pt
#   inflating: content/scores/box_pred_695.pt
#   inflating: content/scores/box_pred_2317.pt
#   inflating: content/scores/box_pred_1805.pt
#   inflating: content/scores/box_pred_1200.pt
#   inflating: content/scores/box_pred_1587.pt
#   inflating: content/scores/box_pred_2766.pt
#   inflating: content/scores/box_pred_2599.pt
#   inflating: content/scores/box_pred_635.pt
#   inflating: content/scores/box_pred_245.pt
#   inflating: content/scores/box_pred_2495.pt
#   inflating: content/scores/box_pred_1948.pt
#   inflating: content/scores/box_pred_2126.pt
#   inflating: content/scores/box_pred_2943.pt
#   inflating: content/scores/box_pred_762.pt
#   inflating: content/scores/box_pred_848.pt
#   inflating: content/scores/box_pred_2897.pt
#   inflating: content/scores/box_pred_813.pt
#   inflating: content/scores/box_pred_1742.pt
#   inflating: content/scores/box_pred_2276.pt
#   inflating: content/scores/box_pred_856.pt
#   inflating: content/scores/box_pred_1284.pt
#   inflating: content/scores/box_pred_3144.pt
#   inflating: content/scores/box_pred_2005.pt
#   inflating: content/scores/box_pred_223.pt
#   inflating: content/scores/box_pred_2802.pt
#   inflating: content/scores/box_pred_2967.pt
#   inflating: content/scores/box_pred_2261.pt
#   inflating: content/scores/box_pred_1577.pt
#   inflating: content/scores/box_pred_1764.pt
#   inflating: content/scores/box_pred_1009.pt
#   inflating: content/scores/box_pred_451.pt
#   inflating: content/scores/box_pred_998.pt
#   inflating: content/scores/box_pred_1357.pt
#   inflating: content/scores/box_pred_1649.pt
#   inflating: content/scores/box_pred_2608.pt
#   inflating: content/scores/box_pred_1415.pt
#   inflating: content/scores/box_pred_254.pt
#   inflating: content/scores/box_pred_1731.pt
#   inflating: content/scores/box_pred_463.pt
#   inflating: content/scores/box_pred_1668.pt
#   inflating: content/scores/box_pred_878.pt
#   inflating: content/scores/box_pred_529.pt
#   inflating: content/scores/box_pred_438.pt
#   inflating: content/scores/box_pred_98.pt
#   inflating: content/scores/box_pred_3259.pt
#   inflating: content/scores/box_pred_2365.pt
#   inflating: content/scores/box_pred_1796.pt
#   inflating: content/scores/box_pred_1448.pt
#   inflating: content/scores/box_pred_84.pt
#   inflating: content/scores/box_pred_2904.pt
#   inflating: content/scores/box_pred_2308.pt
#   inflating: content/scores/box_pred_2635.pt
#   inflating: content/scores/box_pred_2730.pt
#   inflating: content/scores/box_pred_2627.pt
#   inflating: content/scores/box_pred_67.pt
#   inflating: content/scores/box_pred_279.pt
#   inflating: content/scores/box_pred_2001.pt
#   inflating: content/scores/box_pred_569.pt
#   inflating: content/scores/box_pred_1159.pt
#   inflating: content/scores/box_pred_3153.pt
#   inflating: content/scores/box_pred_2981.pt
#   inflating: content/scores/box_pred_3076.pt
#   inflating: content/scores/box_pred_1781.pt
#   inflating: content/scores/box_pred_903.pt
#   inflating: content/scores/box_pred_864.pt
#   inflating: content/scores/box_pred_1991.pt
#   inflating: content/scores/box_pred_1292.pt
#   inflating: content/scores/box_pred_1150.pt
#   inflating: content/scores/box_pred_1011.pt
#   inflating: content/scores/box_pred_3104.pt
#   inflating: content/scores/box_pred_3168.pt
#   inflating: content/scores/box_pred_326.pt
#   inflating: content/scores/box_pred_2361.pt
#   inflating: content/scores/box_pred_2656.pt
#   inflating: content/scores/box_pred_2085.pt
#   inflating: content/scores/box_pred_2062.pt
#   inflating: content/scores/box_pred_897.pt
#   inflating: content/scores/box_pred_888.pt
#   inflating: content/scores/box_pred_2108.pt
#   inflating: content/scores/box_pred_546.pt
#   inflating: content/scores/box_pred_246.pt
#   inflating: content/scores/box_pred_1803.pt
#   inflating: content/scores/box_pred_3251.pt
#   inflating: content/scores/box_pred_89.pt
#   inflating: content/scores/box_pred_1000.pt
#   inflating: content/scores/box_pred_2819.pt
#   inflating: content/scores/box_pred_1274.pt
#   inflating: content/scores/box_pred_933.pt
#   inflating: content/scores/box_pred_1070.pt
#   inflating: content/scores/box_pred_1267.pt
#   inflating: content/scores/box_pred_135.pt
#   inflating: content/scores/box_pred_19.pt
#   inflating: content/scores/box_pred_1863.pt
#   inflating: content/scores/box_pred_1313.pt
#   inflating: content/scores/box_pred_727.pt
#   inflating: content/scores/box_pred_2442.pt
#   inflating: content/scores/box_pred_944.pt
#   inflating: content/scores/box_pred_1269.pt
#   inflating: content/scores/box_pred_1022.pt
#   inflating: content/scores/box_pred_718.pt
#   inflating: content/scores/box_pred_2612.pt
#   inflating: content/scores/box_pred_2437.pt
#   inflating: content/scores/box_pred_2107.pt
#   inflating: content/scores/box_pred_2040.pt
#   inflating: content/scores/box_pred_3077.pt
#   inflating: content/scores/box_pred_172.pt
#   inflating: content/scores/box_pred_273.pt
#   inflating: content/scores/box_pred_2555.pt
#   inflating: content/scores/box_pred_1157.pt
#   inflating: content/scores/box_pred_1927.pt
#   inflating: content/scores/box_pred_2254.pt
#   inflating: content/scores/box_pred_843.pt
#   inflating: content/scores/box_pred_2561.pt
#   inflating: content/scores/box_pred_65.pt
#   inflating: content/scores/box_pred_2336.pt
#   inflating: content/scores/box_pred_158.pt
#   inflating: content/scores/box_pred_1871.pt
#   inflating: content/scores/box_pred_2374.pt
#   inflating: content/scores/box_pred_3092.pt
#   inflating: content/scores/box_pred_1100.pt
#   inflating: content/scores/box_pred_1627.pt
#   inflating: content/scores/box_pred_359.pt
#   inflating: content/scores/box_pred_977.pt
#   inflating: content/scores/box_pred_1425.pt
#   inflating: content/scores/box_pred_1961.pt
#   inflating: content/scores/box_pred_2648.pt
#   inflating: content/scores/box_pred_1922.pt
#   inflating: content/scores/box_pred_2998.pt
#   inflating: content/scores/box_pred_239.pt
#   inflating: content/scores/box_pred_1117.pt
#   inflating: content/scores/box_pred_3218.pt
#   inflating: content/scores/box_pred_3238.pt
#   inflating: content/scores/box_pred_953.pt
#   inflating: content/scores/box_pred_1067.pt
#   inflating: content/scores/box_pred_2668.pt
#   inflating: content/scores/box_pred_2712.pt
#   inflating: content/scores/box_pred_221.pt
#   inflating: content/scores/box_pred_2838.pt
#   inflating: content/scores/box_pred_1107.pt
#   inflating: content/scores/box_pred_533.pt
#   inflating: content/scores/box_pred_1295.pt
#   inflating: content/scores/box_pred_1563.pt
#   inflating: content/scores/box_pred_1088.pt
#   inflating: content/scores/box_pred_2876.pt
#   inflating: content/scores/box_pred_1230.pt
#   inflating: content/scores/box_pred_2249.pt
#   inflating: content/scores/box_pred_405.pt
#   inflating: content/scores/box_pred_317.pt
#   inflating: content/scores/box_pred_457.pt
#   inflating: content/scores/box_pred_2696.pt
#   inflating: content/scores/box_pred_699.pt
#   inflating: content/scores/box_pred_1773.pt
#   inflating: content/scores/box_pred_1842.pt
#   inflating: content/scores/box_pred_3250.pt
#   inflating: content/scores/box_pred_2725.pt
#   inflating: content/scores/box_pred_50.pt
#   inflating: content/scores/box_pred_232.pt
#   inflating: content/scores/box_pred_3143.pt
#   inflating: content/scores/box_pred_1519.pt
#   inflating: content/scores/box_pred_990.pt
#   inflating: content/scores/box_pred_1534.pt
#   inflating: content/scores/box_pred_123.pt
#   inflating: content/scores/box_pred_1346.pt
#   inflating: content/scores/box_pred_1380.pt
#   inflating: content/scores/box_pred_2078.pt
#   inflating: content/scores/box_pred_2709.pt
#   inflating: content/scores/box_pred_539.pt
#   inflating: content/scores/box_pred_472.pt
#   inflating: content/scores/box_pred_1395.pt
#   inflating: content/scores/box_pred_444.pt
#   inflating: content/scores/box_pred_717.pt
#   inflating: content/scores/box_pred_1196.pt
#   inflating: content/scores/box_pred_899.pt
#   inflating: content/scores/box_pred_1867.pt
#   inflating: content/scores/box_pred_2907.pt
#   inflating: content/scores/box_pred_1977.pt
#   inflating: content/scores/box_pred_1140.pt
#   inflating: content/scores/box_pred_29.pt
#   inflating: content/scores/box_pred_47.pt
#   inflating: content/scores/box_pred_2643.pt
#   inflating: content/scores/box_pred_2814.pt
#   inflating: content/scores/box_pred_2990.pt
#   inflating: content/scores/box_pred_413.pt
#   inflating: content/scores/box_pred_2726.pt
#   inflating: content/scores/box_pred_2711.pt
#   inflating: content/scores/box_pred_3044.pt
#   inflating: content/scores/box_pred_2515.pt
#   inflating: content/scores/box_pred_2252.pt
#   inflating: content/scores/box_pred_1349.pt
#   inflating: content/scores/box_pred_1119.pt
#   inflating: content/scores/box_pred_3180.pt
#   inflating: content/scores/box_pred_2504.pt
#   inflating: content/scores/box_pred_277.pt
#   inflating: content/scores/box_pred_839.pt
#   inflating: content/scores/box_pred_1374.pt
#   inflating: content/scores/box_pred_2519.pt
#   inflating: content/scores/box_pred_3254.pt
#   inflating: content/scores/box_pred_652.pt
#   inflating: content/scores/box_pred_1515.pt
#   inflating: content/scores/box_pred_2146.pt
#   inflating: content/scores/box_pred_2592.pt
#   inflating: content/scores/box_pred_3051.pt
#   inflating: content/scores/box_pred_2820.pt
#   inflating: content/scores/box_pred_3057.pt
#   inflating: content/scores/box_pred_1143.pt
#   inflating: content/scores/box_pred_363.pt
#   inflating: content/scores/box_pred_2785.pt
#   inflating: content/scores/box_pred_609.pt
#   inflating: content/scores/box_pred_2359.pt
#   inflating: content/scores/box_pred_1309.pt
#   inflating: content/scores/box_pred_3002.pt
#   inflating: content/scores/box_pred_1744.pt
#   inflating: content/scores/box_pred_3242.pt
#   inflating: content/scores/box_pred_233.pt
#   inflating: content/scores/box_pred_2035.pt
#   inflating: content/scores/box_pred_2436.pt
#   inflating: content/scores/box_pred_1837.pt
#   inflating: content/scores/box_pred_3200.pt
#   inflating: content/scores/box_pred_2906.pt
#   inflating: content/scores/box_pred_2028.pt
#   inflating: content/scores/box_pred_1858.pt
#   inflating: content/scores/box_pred_2318.pt
#   inflating: content/scores/box_pred_338.pt
#   inflating: content/scores/box_pred_1405.pt
#   inflating: content/scores/box_pred_2386.pt
#   inflating: content/scores/box_pred_415.pt
#   inflating: content/scores/box_pred_3118.pt
#   inflating: content/scores/box_pred_844.pt
#   inflating: content/scores/box_pred_2269.pt
#   inflating: content/scores/box_pred_1316.pt
#   inflating: content/scores/box_pred_1381.pt
#   inflating: content/scores/box_pred_2791.pt
#   inflating: content/scores/box_pred_1377.pt
#   inflating: content/scores/box_pred_1952.pt
#   inflating: content/scores/box_pred_1916.pt
#   inflating: content/scores/box_pred_1225.pt
#   inflating: content/scores/box_pred_197.pt
#   inflating: content/scores/box_pred_1165.pt
#   inflating: content/scores/box_pred_2849.pt
#   inflating: content/scores/box_pred_2008.pt
#   inflating: content/scores/box_pred_2631.pt
#   inflating: content/scores/box_pred_404.pt
#   inflating: content/scores/box_pred_2434.pt
#   inflating: content/scores/box_pred_1778.pt
#   inflating: content/scores/box_pred_2370.pt
#   inflating: content/scores/box_pred_1630.pt
#   inflating: content/scores/box_pred_1945.pt
#   inflating: content/scores/box_pred_1525.pt
#   inflating: content/scores/box_pred_483.pt
#   inflating: content/scores/box_pred_1193.pt
#   inflating: content/scores/box_pred_489.pt
#   inflating: content/scores/box_pred_2013.pt
#   inflating: content/scores/box_pred_2970.pt
#   inflating: content/scores/box_pred_548.pt
#   inflating: content/scores/box_pred_2861.pt
#   inflating: content/scores/box_pred_2130.pt
#   inflating: content/scores/box_pred_1393.pt
#   inflating: content/scores/box_pred_675.pt
#   inflating: content/scores/box_pred_515.pt
#   inflating: content/scores/box_pred_1794.pt
#   inflating: content/scores/box_pred_1183.pt
#   inflating: content/scores/box_pred_1642.pt
#   inflating: content/scores/box_pred_1631.pt
#   inflating: content/scores/box_pred_1902.pt
#   inflating: content/scores/box_pred_620.pt
#   inflating: content/scores/box_pred_2982.pt
#   inflating: content/scores/box_pred_3073.pt
#   inflating: content/scores/box_pred_2864.pt
#   inflating: content/scores/box_pred_2782.pt
#   inflating: content/scores/box_pred_3171.pt
#   inflating: content/scores/box_pred_2693.pt
#   inflating: content/scores/box_pred_2940.pt
#   inflating: content/scores/box_pred_3225.pt
#   inflating: content/scores/box_pred_643.pt
#   inflating: content/scores/box_pred_1768.pt
#   inflating: content/scores/box_pred_1066.pt
#   inflating: content/scores/box_pred_2883.pt
#   inflating: content/scores/box_pred_2507.pt
#   inflating: content/scores/box_pred_3205.pt
#   inflating: content/scores/box_pred_2880.pt
#   inflating: content/scores/box_pred_100.pt
#   inflating: content/scores/box_pred_847.pt
#   inflating: content/scores/box_pred_17.pt
#   inflating: content/scores/box_pred_1242.pt
#   inflating: content/scores/box_pred_3189.pt
#   inflating: content/scores/box_pred_280.pt
#   inflating: content/scores/box_pred_1978.pt
#   inflating: content/scores/box_pred_2106.pt
#   inflating: content/scores/box_pred_2094.pt
#   inflating: content/scores/box_pred_356.pt
#   inflating: content/scores/box_pred_134.pt
#   inflating: content/scores/box_pred_705.pt
#   inflating: content/scores/box_pred_2398.pt
#   inflating: content/scores/box_pred_556.pt
#   inflating: content/scores/box_pred_1979.pt
#   inflating: content/scores/box_pred_826.pt
#   inflating: content/scores/box_pred_2296.pt
#   inflating: content/scores/box_pred_1682.pt
#   inflating: content/scores/box_pred_1856.pt
#   inflating: content/scores/box_pred_519.pt
#   inflating: content/scores/box_pred_2273.pt
#   inflating: content/scores/box_pred_3186.pt
#   inflating: content/scores/box_pred_694.pt
#   inflating: content/scores/box_pred_318.pt
#   inflating: content/scores/box_pred_1540.pt
#   inflating: content/scores/box_pred_756.pt
#   inflating: content/scores/box_pred_1947.pt
#   inflating: content/scores/box_pred_792.pt
#   inflating: content/scores/box_pred_796.pt
#   inflating: content/scores/box_pred_1943.pt
#   inflating: content/scores/box_pred_2729.pt
#   inflating: content/scores/box_pred_3179.pt
#   inflating: content/scores/box_pred_896.pt
#   inflating: content/scores/box_pred_2480.pt
#   inflating: content/scores/box_pred_1122.pt
#   inflating: content/scores/box_pred_2732.pt
#   inflating: content/scores/box_pred_614.pt
#   inflating: content/scores/box_pred_857.pt
#   inflating: content/scores/box_pred_1226.pt
#   inflating: content/scores/box_pred_982.pt
#   inflating: content/scores/box_pred_2018.pt
#   inflating: content/scores/box_pred_1034.pt
#   inflating: content/scores/box_pred_266.pt
#   inflating: content/scores/box_pred_560.pt
#   inflating: content/scores/box_pred_1640.pt
#   inflating: content/scores/box_pred_441.pt
#   inflating: content/scores/box_pred_364.pt
#   inflating: content/scores/box_pred_1993.pt
#   inflating: content/scores/box_pred_2171.pt
#   inflating: content/scores/box_pred_3220.pt
#   inflating: content/scores/box_pred_1612.pt
#   inflating: content/scores/box_pred_2316.pt
#   inflating: content/scores/box_pred_3048.pt
#   inflating: content/scores/box_pred_1760.pt
#   inflating: content/scores/box_pred_822.pt
#   inflating: content/scores/box_pred_3072.pt
#   inflating: content/scores/box_pred_1390.pt
#   inflating: content/scores/box_pred_375.pt
#   inflating: content/scores/box_pred_2746.pt
#   inflating: content/scores/box_pred_2113.pt
#   inflating: content/scores/box_pred_1537.pt
#   inflating: content/scores/box_pred_679.pt
#   inflating: content/scores/box_pred_1617.pt
#   inflating: content/scores/box_pred_1307.pt
#   inflating: content/scores/box_pred_401.pt
#   inflating: content/scores/box_pred_3236.pt
#   inflating: content/scores/box_pred_3034.pt
#   inflating: content/scores/box_pred_2913.pt
#   inflating: content/scores/box_pred_2552.pt
#   inflating: content/scores/box_pred_412.pt
#   inflating: content/scores/box_pred_3230.pt
#   inflating: content/scores/box_pred_2926.pt
#   inflating: content/scores/box_pred_2858.pt
#   inflating: content/scores/box_pred_2790.pt
#   inflating: content/scores/box_pred_2032.pt
#   inflating: content/scores/box_pred_2860.pt
#   inflating: content/scores/box_pred_3030.pt
#   inflating: content/scores/box_pred_530.pt
#   inflating: content/scores/box_pred_2473.pt
#   inflating: content/scores/box_pred_780.pt
#   inflating: content/scores/box_pred_926.pt
#   inflating: content/scores/box_pred_321.pt
#   inflating: content/scores/box_pred_1497.pt
#   inflating: content/scores/box_pred_1953.pt
#   inflating: content/scores/box_pred_2379.pt
#   inflating: content/scores/box_pred_2835.pt
#   inflating: content/scores/box_pred_2079.pt
#   inflating: content/scores/box_pred_1539.pt
#   inflating: content/scores/box_pred_597.pt
#   inflating: content/scores/box_pred_1211.pt
#   inflating: content/scores/box_pred_988.pt
#   inflating: content/scores/box_pred_1492.pt
#   inflating: content/scores/box_pred_1886.pt
#   inflating: content/scores/box_pred_1173.pt
#   inflating: content/scores/box_pred_1458.pt
#   inflating: content/scores/box_pred_3112.pt
#   inflating: content/scores/box_pred_1470.pt
#   inflating: content/scores/box_pred_284.pt
#   inflating: content/scores/box_pred_2607.pt
#   inflating: content/scores/box_pred_2695.pt
#   inflating: content/scores/box_pred_1111.pt
#   inflating: content/scores/box_pred_1265.pt
#   inflating: content/scores/box_pred_562.pt
#   inflating: content/scores/box_pred_1102.pt
#   inflating: content/scores/box_pred_3070.pt
#   inflating: content/scores/box_pred_142.pt
#   inflating: content/scores/box_pred_3094.pt
#   inflating: content/scores/box_pred_1883.pt
#   inflating: content/scores/box_pred_765.pt
#   inflating: content/scores/box_pred_231.pt
#   inflating: content/scores/box_pred_13.pt
#   inflating: content/scores/box_pred_1176.pt
#   inflating: content/scores/box_pred_881.pt
#   inflating: content/scores/box_pred_1368.pt
#   inflating: content/scores/box_pred_2953.pt
#   inflating: content/scores/box_pred_1203.pt
#   inflating: content/scores/box_pred_735.pt
#   inflating: content/scores/box_pred_104.pt
#   inflating: content/scores/box_pred_2750.pt
#   inflating: content/scores/box_pred_263.pt
#   inflating: content/scores/box_pred_851.pt
#   inflating: content/scores/box_pred_1797.pt
#   inflating: content/scores/box_pred_3255.pt
#   inflating: content/scores/box_pred_789.pt
#   inflating: content/scores/box_pred_1416.pt
#   inflating: content/scores/box_pred_1678.pt
#   inflating: content/scores/box_pred_741.pt
#   inflating: content/scores/box_pred_952.pt
#   inflating: content/scores/box_pred_769.pt
#   inflating: content/scores/box_pred_3121.pt
#   inflating: content/scores/box_pred_1801.pt
#   inflating: content/scores/box_pred_235.pt
#   inflating: content/scores/box_pred_3111.pt
#   inflating: content/scores/box_pred_2633.pt
#   inflating: content/scores/box_pred_3246.pt
#   inflating: content/scores/box_pred_954.pt
#   inflating: content/scores/box_pred_341.pt
#   inflating: content/scores/box_pred_1136.pt
#   inflating: content/scores/box_pred_491.pt
#   inflating: content/scores/box_pred_2939.pt
#   inflating: content/scores/box_pred_870.pt
#   inflating: content/scores/box_pred_854.pt
#   inflating: content/scores/box_pred_2623.pt
#   inflating: content/scores/box_pred_1687.pt
#   inflating: content/scores/box_pred_812.pt
#   inflating: content/scores/box_pred_970.pt
#   inflating: content/scores/box_pred_34.pt
#   inflating: content/scores/box_pred_1658.pt
#   inflating: content/scores/box_pred_242.pt
#   inflating: content/scores/box_pred_1450.pt
#   inflating: content/scores/box_pred_1714.pt
#   inflating: content/scores/box_pred_2792.pt
#   inflating: content/scores/box_pred_2463.pt
#   inflating: content/scores/box_pred_2829.pt
#   inflating: content/scores/box_pred_1250.pt
#   inflating: content/scores/box_pred_2490.pt
#   inflating: content/scores/box_pred_2003.pt
#   inflating: content/scores/box_pred_1819.pt
#   inflating: content/scores/box_pred_37.pt
#   inflating: content/scores/box_pred_3052.pt
#   inflating: content/scores/box_pred_1407.pt
#   inflating: content/scores/box_pred_1321.pt
#   inflating: content/scores/box_pred_382.pt
#   inflating: content/scores/box_pred_3125.pt
#   inflating: content/scores/box_pred_2248.pt
#   inflating: content/scores/box_pred_2824.pt
#   inflating: content/scores/box_pred_151.pt
#   inflating: content/scores/box_pred_181.pt
#   inflating: content/scores/box_pred_2412.pt
#   inflating: content/scores/box_pred_732.pt
#   inflating: content/scores/box_pred_76.pt
#   inflating: content/scores/box_pred_2574.pt
#   inflating: content/scores/box_pred_1275.pt
#   inflating: content/scores/box_pred_1081.pt
#   inflating: content/scores/box_pred_3084.pt
#   inflating: content/scores/box_pred_1726.pt
#   inflating: content/scores/box_pred_1743.pt
#   inflating: content/scores/box_pred_2987.pt
#   inflating: content/scores/box_pred_2692.pt
#   inflating: content/scores/box_pred_2347.pt
#   inflating: content/scores/box_pred_1618.pt
#   inflating: content/scores/box_pred_3050.pt
#   inflating: content/scores/box_pred_1462.pt
#   inflating: content/scores/box_pred_1820.pt
#   inflating: content/scores/box_pred_1970.pt
#   inflating: content/scores/box_pred_410.pt
#   inflating: content/scores/box_pred_800.pt
#   inflating: content/scores/box_pred_958.pt
#   inflating: content/scores/box_pred_3139.pt
#   inflating: content/scores/box_pred_1428.pt
#   inflating: content/scores/box_pred_951.pt
#   inflating: content/scores/box_pred_3018.pt
#   inflating: content/scores/box_pred_804.pt
#   inflating: content/scores/box_pred_2381.pt
#   inflating: content/scores/box_pred_2840.pt
#   inflating: content/scores/box_pred_837.pt
#   inflating: content/scores/box_pred_1320.pt
#   inflating: content/scores/box_pred_129.pt
#   inflating: content/scores/box_pred_2784.pt
#   inflating: content/scores/box_pred_911.pt
#   inflating: content/scores/box_pred_99.pt
#   inflating: content/scores/box_pred_1508.pt
#   inflating: content/scores/box_pred_3067.pt
#   inflating: content/scores/box_pred_2741.pt
#   inflating: content/scores/box_pred_2060.pt
#   inflating: content/scores/box_pred_1082.pt
#   inflating: content/scores/box_pred_1843.pt
#   inflating: content/scores/box_pred_3027.pt
#   inflating: content/scores/box_pred_2505.pt
#   inflating: content/scores/box_pred_90.pt
#   inflating: content/scores/box_pred_1717.pt
#   inflating: content/scores/box_pred_3169.pt
#   inflating: content/scores/box_pred_1464.pt
#   inflating: content/scores/box_pred_594.pt
#   inflating: content/scores/box_pred_2917.pt
#   inflating: content/scores/box_pred_794.pt
#   inflating: content/scores/box_pred_340.pt
#   inflating: content/scores/box_pred_1096.pt
#   inflating: content/scores/box_pred_2112.pt
#   inflating: content/scores/box_pred_1043.pt
#   inflating: content/scores/box_pred_2277.pt
#   inflating: content/scores/box_pred_20.pt
#   inflating: content/scores/box_pred_1249.pt
#   inflating: content/scores/box_pred_522.pt
#   inflating: content/scores/box_pred_1487.pt
#   inflating: content/scores/box_pred_564.pt
#   inflating: content/scores/box_pred_1541.pt
#   inflating: content/scores/box_pred_1980.pt
#   inflating: content/scores/box_pred_2433.pt
#   inflating: content/scores/box_pred_475.pt
#   inflating: content/scores/box_pred_1904.pt
#   inflating: content/scores/box_pred_2780.pt
#   inflating: content/scores/box_pred_272.pt
#   inflating: content/scores/box_pred_1864.pt
#   inflating: content/scores/box_pred_1908.pt
#   inflating: content/scores/box_pred_2828.pt
#   inflating: content/scores/box_pred_574.pt
#   inflating: content/scores/box_pred_2664.pt
#   inflating: content/scores/box_pred_1065.pt
#   inflating: content/scores/box_pred_2180.pt
#   inflating: content/scores/box_pred_721.pt
#   inflating: content/scores/box_pred_168.pt
#   inflating: content/scores/box_pred_537.pt
#   inflating: content/scores/box_pred_915.pt
#   inflating: content/scores/box_pred_999.pt
#   inflating: content/scores/box_pred_1206.pt
#   inflating: content/scores/box_pred_2677.pt
#   inflating: content/scores/box_pred_1599.pt
#   inflating: content/scores/box_pred_128.pt
#   inflating: content/scores/box_pred_1861.pt
#   inflating: content/scores/box_pred_1485.pt
#   inflating: content/scores/box_pred_105.pt
#   inflating: content/scores/box_pred_2144.pt
#   inflating: content/scores/box_pred_28.pt
#   inflating: content/scores/box_pred_2135.pt
#   inflating: content/scores/box_pred_919.pt
#   inflating: content/scores/box_pred_1728.pt
#   inflating: content/scores/box_pred_2244.pt
#   inflating: content/scores/box_pred_2291.pt
#   inflating: content/scores/box_pred_2447.pt
#   inflating: content/scores/box_pred_1547.pt
#   inflating: content/scores/box_pred_408.pt
#   inflating: content/scores/box_pred_2307.pt
#   inflating: content/scores/box_pred_764.pt
#   inflating: content/scores/box_pred_889.pt
#   inflating: content/scores/box_pred_2450.pt
#   inflating: content/scores/box_pred_2728.pt
#   inflating: content/scores/box_pred_2775.pt
#   inflating: content/scores/box_pred_1248.pt
#   inflating: content/scores/box_pred_1544.pt
#   inflating: content/scores/box_pred_2797.pt
#   inflating: content/scores/box_pred_1134.pt
#   inflating: content/scores/box_pred_1946.pt
#   inflating: content/scores/box_pred_1141.pt
#   inflating: content/scores/box_pred_3032.pt
#   inflating: content/scores/box_pred_367.pt
#   inflating: content/scores/box_pred_192.pt
#   inflating: content/scores/box_pred_456.pt
#   inflating: content/scores/box_pred_2530.pt
#   inflating: content/scores/box_pred_312.pt
#   inflating: content/scores/box_pred_1597.pt
#   inflating: content/scores/box_pred_1286.pt
#   inflating: content/scores/box_pred_924.pt
#   inflating: content/scores/box_pred_541.pt
#   inflating: content/scores/box_pred_78.pt
#   inflating: content/scores/box_pred_882.pt
#   inflating: content/scores/box_pred_2482.pt
#   inflating: content/scores/box_pred_2733.pt
#   inflating: content/scores/box_pred_2641.pt
#   inflating: content/scores/box_pred_2152.pt
#   inflating: content/scores/box_pred_1987.pt
#   inflating: content/scores/box_pred_2910.pt
#   inflating: content/scores/box_pred_1791.pt
#   inflating: content/scores/box_pred_294.pt
#   inflating: content/scores/box_pred_923.pt
#   inflating: content/scores/box_pred_473.pt
#   inflating: content/scores/box_pred_1126.pt
#   inflating: content/scores/box_pred_2068.pt
#   inflating: content/scores/box_pred_3132.pt
#   inflating: content/scores/box_pred_1956.pt
#   inflating: content/scores/box_pred_3176.pt
#   inflating: content/scores/box_pred_1506.pt
#   inflating: content/scores/box_pred_3013.pt
#   inflating: content/scores/box_pred_1426.pt
#   inflating: content/scores/box_pred_39.pt
#   inflating: content/scores/box_pred_606.pt
#   inflating: content/scores/box_pred_1171.pt
#   inflating: content/scores/box_pred_2023.pt
#   inflating: content/scores/box_pred_658.pt
#   inflating: content/scores/box_pred_1838.pt
#   inflating: content/scores/box_pred_1695.pt
#   inflating: content/scores/box_pred_77.pt
#   inflating: content/scores/box_pred_2147.pt
#   inflating: content/scores/box_pred_2428.pt
#   inflating: content/scores/box_pred_2421.pt
#   inflating: content/scores/box_pred_2036.pt
#   inflating: content/scores/box_pred_2935.pt
#   inflating: content/scores/box_pred_2821.pt
#   inflating: content/scores/box_pred_282.pt
#   inflating: content/scores/box_pred_393.pt
#   inflating: content/scores/box_pred_2395.pt
#   inflating: content/scores/box_pred_1788.pt
#   inflating: content/scores/box_pred_3221.pt
#   inflating: content/scores/box_pred_2536.pt
#   inflating: content/scores/box_pred_2030.pt
#   inflating: content/scores/box_pred_1578.pt
#   inflating: content/scores/box_pred_660.pt
#   inflating: content/scores/box_pred_1049.pt
#   inflating: content/scores/box_pred_102.pt
#   inflating: content/scores/box_pred_2100.pt
#   inflating: content/scores/box_pred_2311.pt
#   inflating: content/scores/box_pred_1199.pt
#   inflating: content/scores/box_pred_1207.pt
#   inflating: content/scores/box_pred_665.pt
#   inflating: content/scores/box_pred_300.pt
#   inflating: content/scores/box_pred_2011.pt
#   inflating: content/scores/box_pred_867.pt
#   inflating: content/scores/box_pred_1919.pt
#   inflating: content/scores/box_pred_2189.pt
#   inflating: content/scores/box_pred_739.pt
#   inflating: content/scores/box_pred_1092.pt
#   inflating: content/scores/box_pred_447.pt
#   inflating: content/scores/box_pred_237.pt
#   inflating: content/scores/box_pred_932.pt
#   inflating: content/scores/box_pred_195.pt
#   inflating: content/scores/box_pred_2415.pt
#   inflating: content/scores/box_pred_1182.pt
#   inflating: content/scores/box_pred_3264.pt
#   inflating: content/scores/box_pred_2410.pt
#   inflating: content/scores/box_pred_1737.pt
#   inflating: content/scores/box_pred_1246.pt
#   inflating: content/scores/box_pred_1620.pt
#   inflating: content/scores/box_pred_193.pt
#   inflating: content/scores/box_pred_3237.pt
#   inflating: content/scores/box_pred_1178.pt
#   inflating: content/scores/box_pred_558.pt
#   inflating: content/scores/box_pred_677.pt
#   inflating: content/scores/box_pred_774.pt
#   inflating: content/scores/box_pred_91.pt
#   inflating: content/scores/box_pred_657.pt
#   inflating: content/scores/box_pred_2491.pt
#   inflating: content/scores/box_pred_2136.pt
#   inflating: content/scores/box_pred_1533.pt
#   inflating: content/scores/box_pred_1025.pt
#   inflating: content/scores/box_pred_218.pt
#   inflating: content/scores/box_pred_1317.pt
#   inflating: content/scores/box_pred_2329.pt
#   inflating: content/scores/box_pred_3202.pt
#   inflating: content/scores/box_pred_886.pt
#   inflating: content/scores/box_pred_2223.pt
#   inflating: content/scores/box_pred_2243.pt
#   inflating: content/scores/box_pred_1040.pt
#   inflating: content/scores/box_pred_2580.pt
#   inflating: content/scores/box_pred_3164.pt
#   inflating: content/scores/box_pred_163.pt
#   inflating: content/scores/box_pred_1518.pt
#   inflating: content/scores/box_pred_136.pt
#   inflating: content/scores/box_pred_1.pt
#   inflating: content/scores/box_pred_2125.pt
#   inflating: content/scores/box_pred_2806.pt
#   inflating: content/scores/box_pred_156.pt
#   inflating: content/scores/box_pred_3106.pt
#   inflating: content/scores/box_pred_782.pt
#   inflating: content/scores/box_pred_876.pt
#   inflating: content/scores/box_pred_1310.pt
#   inflating: content/scores/box_pred_2206.pt
#   inflating: content/scores/box_pred_1384.pt
#   inflating: content/scores/box_pred_890.pt
#   inflating: content/scores/box_pred_2911.pt
#   inflating: content/scores/box_pred_1403.pt
#   inflating: content/scores/box_pred_323.pt
#   inflating: content/scores/box_pred_1873.pt
#   inflating: content/scores/box_pred_2455.pt
#   inflating: content/scores/box_pred_590.pt
#   inflating: content/scores/box_pred_2647.pt
#   inflating: content/scores/box_pred_2430.pt
#   inflating: content/scores/box_pred_3005.pt
#   inflating: content/scores/box_pred_1885.pt
#   inflating: content/scores/box_pred_423.pt
#   inflating: content/scores/box_pred_980.pt
#   inflating: content/scores/box_pred_900.pt
#   inflating: content/scores/box_pred_2479.pt
#   inflating: content/scores/box_pred_443.pt
#   inflating: content/scores/box_pred_2217.pt
#   inflating: content/scores/box_pred_2326.pt
#   inflating: content/scores/box_pred_2541.pt
#   inflating: content/scores/box_pred_750.pt
#   inflating: content/scores/box_pred_3257.pt
#   inflating: content/scores/box_pred_2533.pt
#   inflating: content/scores/box_pred_967.pt
#   inflating: content/scores/box_pred_2878.pt
#   inflating: content/scores/box_pred_2951.pt
#   inflating: content/scores/box_pred_1457.pt
#   inflating: content/scores/box_pred_791.pt
#   inflating: content/scores/box_pred_276.pt
#   inflating: content/scores/box_pred_828.pt
#   inflating: content/scores/box_pred_2229.pt
#   inflating: content/scores/box_pred_1351.pt
#   inflating: content/scores/box_pred_1988.pt
#   inflating: content/scores/box_pred_1762.pt
#   inflating: content/scores/box_pred_1097.pt
#   inflating: content/scores/box_pred_2977.pt
#   inflating: content/scores/box_pred_666.pt
#   inflating: content/scores/box_pred_2659.pt
#   inflating: content/scores/box_pred_492.pt
#   inflating: content/scores/box_pred_502.pt
#   inflating: content/scores/box_pred_1076.pt
#   inflating: content/scores/box_pred_2884.pt
#   inflating: content/scores/box_pred_2604.pt
#   inflating: content/scores/box_pred_1804.pt
#   inflating: content/scores/box_pred_103.pt
#   inflating: content/scores/box_pred_674.pt
#   inflating: content/scores/box_pred_2073.pt
#   inflating: content/scores/box_pred_1846.pt
#   inflating: content/scores/box_pred_618.pt
#   inflating: content/scores/box_pred_1591.pt
#   inflating: content/scores/box_pred_2102.pt
#   inflating: content/scores/box_pred_3001.pt
#   inflating: content/scores/box_pred_1997.pt
#   inflating: content/scores/box_pred_371.pt
#   inflating: content/scores/box_pred_984.pt
#   inflating: content/scores/box_pred_3146.pt
#   inflating: content/scores/box_pred_1087.pt
#   inflating: content/scores/box_pred_1984.pt
#   inflating: content/scores/box_pred_2526.pt
#   inflating: content/scores/box_pred_2070.pt
#   inflating: content/scores/box_pred_2211.pt
#   inflating: content/scores/box_pred_1421.pt
#   inflating: content/scores/box_pred_384.pt
#   inflating: content/scores/box_pred_1779.pt
#   inflating: content/scores/box_pred_2991.pt
#   inflating: content/scores/box_pred_2632.pt
#   inflating: content/scores/box_pred_588.pt
#   inflating: content/scores/box_pred_2218.pt
#   inflating: content/scores/box_pred_2279.pt
#   inflating: content/scores/box_pred_2764.pt
#   inflating: content/scores/box_pred_286.pt
#   inflating: content/scores/box_pred_3193.pt
#   inflating: content/scores/box_pred_1565.pt
#   inflating: content/scores/box_pred_521.pt
#   inflating: content/scores/box_pred_672.pt
#   inflating: content/scores/box_pred_1884.pt
#   inflating: content/scores/box_pred_542.pt
#   inflating: content/scores/box_pred_681.pt
#   inflating: content/scores/box_pred_1800.pt
#   inflating: content/scores/box_pred_1376.pt
#   inflating: content/scores/box_pred_72.pt
#   inflating: content/scores/box_pred_1366.pt
#   inflating: content/scores/box_pred_3080.pt
#   inflating: content/scores/box_pred_1638.pt
#   inflating: content/scores/box_pred_2522.pt
#   inflating: content/scores/box_pred_303.pt
#   inflating: content/scores/box_pred_619.pt
#   inflating: content/scores/box_pred_2874.pt
#   inflating: content/scores/box_pred_1772.pt
#   inflating: content/scores/box_pred_653.pt
#   inflating: content/scores/box_pred_2477.pt
#   inflating: content/scores/box_pred_1604.pt
#   inflating: content/scores/box_pred_2674.pt
#   inflating: content/scores/box_pred_860.pt
#   inflating: content/scores/box_pred_2506.pt
#   inflating: content/scores/box_pred_532.pt
#   inflating: content/scores/box_pred_2744.pt
#   inflating: content/scores/box_pred_490.pt
#   inflating: content/scores/box_pred_2979.pt
#   inflating: content/scores/box_pred_2378.pt
#   inflating: content/scores/box_pred_166.pt
#   inflating: content/scores/box_pred_2161.pt
#   inflating: content/scores/box_pred_1339.pt
#   inflating: content/scores/box_pred_2889.pt
#   inflating: content/scores/box_pred_3091.pt
#   inflating: content/scores/box_pred_1394.pt
#   inflating: content/scores/box_pred_1513.pt
#   inflating: content/scores/box_pred_2686.pt
#   inflating: content/scores/box_pred_2964.pt
#   inflating: content/scores/box_pred_3024.pt
#   inflating: content/scores/box_pred_2894.pt
#   inflating: content/scores/box_pred_2010.pt
#   inflating: content/scores/box_pred_1319.pt
#   inflating: content/scores/box_pred_1306.pt
#   inflating: content/scores/box_pred_3208.pt
#   inflating: content/scores/box_pred_38.pt
#   inflating: content/scores/box_pred_928.pt
#   inflating: content/scores/box_pred_1872.pt
#   inflating: content/scores/box_pred_182.pt
#   inflating: content/scores/box_pred_1669.pt
#   inflating: content/scores/box_pred_2610.pt
#   inflating: content/scores/box_pred_164.pt
#   inflating: content/scores/box_pred_2225.pt
#   inflating: content/scores/box_pred_1343.pt
#   inflating: content/scores/box_pred_1711.pt
#   inflating: content/scores/box_pred_2256.pt
#   inflating: content/scores/box_pred_2722.pt
#   inflating: content/scores/box_pred_845.pt
#   inflating: content/scores/box_pred_428.pt
#   inflating: content/scores/box_pred_2328.pt
#   inflating: content/scores/box_pred_836.pt
#   inflating: content/scores/box_pred_1449.pt
#   inflating: content/scores/box_pred_1657.pt
#   inflating: content/scores/box_pred_3097.pt
#   inflating: content/scores/box_pred_468.pt
#   inflating: content/scores/box_pred_1305.pt
#   inflating: content/scores/box_pred_1078.pt
#   inflating: content/scores/box_pred_1382.pt
#   inflating: content/scores/box_pred_1204.pt
#   inflating: content/scores/box_pred_1408.pt
#   inflating: content/scores/box_pred_2591.pt
#   inflating: content/scores/box_pred_3247.pt
#   inflating: content/scores/box_pred_2209.pt
#   inflating: content/scores/box_pred_2405.pt
#   inflating: content/scores/box_pred_3011.pt
#   inflating: content/scores/box_pred_358.pt
#   inflating: content/scores/box_pred_75.pt
#   inflating: content/scores/box_pred_2119.pt
#   inflating: content/scores/box_pred_145.pt
#   inflating: content/scores/box_pred_1367.pt
#   inflating: content/scores/box_pred_1280.pt
#   inflating: content/scores/box_pred_2645.pt
#   inflating: content/scores/box_pred_2971.pt
#   inflating: content/scores/box_pred_1680.pt
#   inflating: content/scores/box_pred_1004.pt
#   inflating: content/scores/box_pred_2120.pt
#   inflating: content/scores/box_pred_1918.pt
#   inflating: content/scores/box_pred_1218.pt
#   inflating: content/scores/box_pred_148.pt
#   inflating: content/scores/box_pred_906.pt
#   inflating: content/scores/box_pred_32.pt
#   inflating: content/scores/box_pred_1706.pt
#   inflating: content/scores/box_pred_2898.pt
#   inflating: content/scores/box_pred_1921.pt
#   inflating: content/scores/box_pred_2899.pt
#   inflating: content/scores/box_pred_1887.pt
#   inflating: content/scores/box_pred_2172.pt
#   inflating: content/scores/box_pred_450.pt
#   inflating: content/scores/box_pred_114.pt
#   inflating: content/scores/box_pred_960.pt
#   inflating: content/scores/box_pred_2151.pt
#   inflating: content/scores/box_pred_1303.pt
#   inflating: content/scores/box_pred_978.pt
#   inflating: content/scores/box_pred_1982.pt
#   inflating: content/scores/box_pred_1664.pt
#   inflating: content/scores/box_pred_2265.pt
#   inflating: content/scores/box_pred_2134.pt
#   inflating: content/scores/box_pred_2049.pt
#   inflating: content/scores/box_pred_2984.pt
#   inflating: content/scores/box_pred_2024.pt
#   inflating: content/scores/box_pred_215.pt
#   inflating: content/scores/box_pred_995.pt
#   inflating: content/scores/box_pred_3160.pt
#   inflating: content/scores/box_pred_1776.pt
#   inflating: content/scores/box_pred_1745.pt
#   inflating: content/scores/box_pred_2240.pt
#   inflating: content/scores/box_pred_2048.pt
#   inflating: content/scores/box_pred_918.pt
#   inflating: content/scores/box_pred_1482.pt
#   inflating: content/scores/box_pred_1179.pt
#   inflating: content/scores/box_pred_1981.pt
#   inflating: content/scores/box_pred_1621.pt
#   inflating: content/scores/box_pred_1808.pt
#   inflating: content/scores/box_pred_2042.pt
#   inflating: content/scores/box_pred_2754.pt
#   inflating: content/scores/box_pred_1315.pt
#   inflating: content/scores/box_pred_3223.pt
#   inflating: content/scores/box_pred_3078.pt
#   inflating: content/scores/box_pred_617.pt
#   inflating: content/scores/box_pred_3232.pt
#   inflating: content/scores/box_pred_692.pt
#   inflating: content/scores/box_pred_1104.pt
#   inflating: content/scores/box_pred_471.pt
#   inflating: content/scores/box_pred_942.pt
#   inflating: content/scores/box_pred_1522.pt
#   inflating: content/scores/box_pred_1098.pt
#   inflating: content/scores/box_pred_2975.pt
#   inflating: content/scores/box_pred_1285.pt
#   inflating: content/scores/box_pred_1692.pt
#   inflating: content/scores/box_pred_1184.pt
#   inflating: content/scores/box_pred_316.pt
#   inflating: content/scores/box_pred_152.pt
#   inflating: content/scores/box_pred_1558.pt
#   inflating: content/scores/box_pred_2338.pt
#   inflating: content/scores/box_pred_2123.pt
#   inflating: content/scores/box_pred_2767.pt
#   inflating: content/scores/box_pred_697.pt
#   inflating: content/scores/box_pred_2163.pt
#   inflating: content/scores/box_pred_1266.pt
#   inflating: content/scores/box_pred_2353.pt
#   inflating: content/scores/box_pred_2399.pt
#   inflating: content/scores/box_pred_2524.pt
#   inflating: content/scores/box_pred_1356.pt
#   inflating: content/scores/box_pred_704.pt
#   inflating: content/scores/box_pred_248.pt
#   inflating: content/scores/box_pred_3127.pt
#   inflating: content/scores/box_pred_1505.pt
#   inflating: content/scores/box_pred_1129.pt
#   inflating: content/scores/box_pred_2041.pt
#   inflating: content/scores/box_pred_1401.pt
#   inflating: content/scores/box_pred_190.pt
#   inflating: content/scores/box_pred_1644.pt
#   inflating: content/scores/box_pred_391.pt
#   inflating: content/scores/box_pred_2302.pt
#   inflating: content/scores/box_pred_59.pt
#   inflating: content/scores/box_pred_2022.pt
#   inflating: content/scores/box_pred_2661.pt
#   inflating: content/scores/box_pred_287.pt
#   inflating: content/scores/box_pred_1899.pt
#   inflating: content/scores/box_pred_781.pt
#   inflating: content/scores/box_pred_1181.pt
#   inflating: content/scores/box_pred_861.pt
#   inflating: content/scores/box_pred_1821.pt
#   inflating: content/scores/box_pred_1051.pt
#   inflating: content/scores/box_pred_840.pt
#   inflating: content/scores/box_pred_1960.pt
#   inflating: content/scores/box_pred_2666.pt
#   inflating: content/scores/box_pred_1424.pt
#   inflating: content/scores/box_pred_3101.pt
#   inflating: content/scores/box_pred_2031.pt
#   inflating: content/scores/box_pred_2587.pt
#   inflating: content/scores/box_pred_2281.pt
#   inflating: content/scores/box_pred_550.pt
#   inflating: content/scores/box_pred_517.pt
#   inflating: content/scores/box_pred_1046.pt
#   inflating: content/scores/box_pred_949.pt
#   inflating: content/scores/box_pred_1452.pt
#   inflating: content/scores/box_pred_2657.pt
#   inflating: content/scores/box_pred_93.pt
#   inflating: content/scores/box_pred_1567.pt
#   inflating: content/scores/box_pred_3004.pt
#   inflating: content/scores/box_pred_3022.pt
#   inflating: content/scores/box_pred_1546.pt
#   inflating: content/scores/box_pred_433.pt
#   inflating: content/scores/box_pred_702.pt
#   inflating: content/scores/box_pred_575.pt
#   inflating: content/scores/box_pred_2301.pt
#   inflating: content/scores/box_pred_2485.pt
#   inflating: content/scores/box_pred_771.pt
#   inflating: content/scores/box_pred_725.pt
#   inflating: content/scores/box_pred_1001.pt
#   inflating: content/scores/box_pred_1047.pt
#   inflating: content/scores/box_pred_1679.pt
#   inflating: content/scores/box_pred_1062.pt
#   inflating: content/scores/box_pred_729.pt
#   inflating: content/scores/box_pred_58.pt
#   inflating: content/scores/box_pred_2839.pt
# ...
#   inflating: content/scores/box_pred_1799.pt
#   inflating: content/scores/box_pred_1058.pt
#   inflating: content/scores/box_pred_2169.pt
#   inflating: content/scores/box_pred_850.pt
#   inflating: content/scores/box_pred_3234.pt
#   inflating: content/scores/box_pred_3066.pt
#   inflating: content/scores/box_pred_2713.pt
#   inflating: content/scores/box_pred_1154.pt
#   inflating: content/scores/box_pred_366.pt
#   inflating: content/scores/box_pred_3159.pt
#   inflating: content/scores/box_pred_10.pt
#   inflating: content/scores/box_pred_1613.pt
#   inflating: content/scores/box_pred_2352.pt
#   inflating: content/scores/box_pred_2422.pt
#   inflating: content/scores/box_pred_3229.pt
#   inflating: content/scores/box_pred_930.pt
#   inflating: content/scores/box_pred_130.pt
#   inflating: content/scores/box_pred_2481.pt
#   inflating: content/scores/box_pred_603.pt
#   inflating: content/scores/box_pred_991.pt
#   inflating: content/scores/box_pred_1322.pt
#   inflating: content/scores/box_pred_1610.pt
#   inflating: content/scores/box_pred_346.pt
#   inflating: content/scores/box_pred_3120.pt
#   inflating: content/scores/box_pred_816.pt
#   inflating: content/scores/box_pred_2101.pt
#   inflating: content/scores/box_pred_1770.pt
#   inflating: content/scores/box_pred_1261.pt
#   inflating: content/scores/box_pred_1672.pt
#   inflating: content/scores/box_pred_736.pt
#   inflating: content/scores/box_pred_2464.pt
#   inflating: content/scores/box_pred_872.pt
#   inflating: content/scores/box_pred_1002.pt
#   inflating: content/scores/box_pred_3150.pt
#   inflating: content/scores/box_pred_938.pt
#   inflating: content/scores/box_pred_891.pt
#   inflating: content/scores/box_pred_807.pt
#   inflating: content/scores/box_pred_1708.pt
#   inflating: content/scores/box_pred_1048.pt
#   inflating: content/scores/box_pred_1532.pt
#   inflating: content/scores/box_pred_2617.pt
#   inflating: content/scores/box_pred_3239.pt
#   inflating: content/scores/box_pred_1569.pt
#   inflating: content/scores/box_pred_2220.pt
#   inflating: content/scores/box_pred_1069.pt
#   inflating: content/scores/box_pred_626.pt
#   inflating: content/scores/box_pred_2385.pt
#   inflating: content/scores/box_pred_2110.pt
#   inflating: content/scores/box_pred_3110.pt
#   inflating: content/scores/box_pred_271.pt
#   inflating: content/scores/box_pred_2496.pt
#   inflating: content/scores/box_pred_612.pt
#   inflating: content/scores/box_pred_633.pt
#   inflating: content/scores/box_pred_2581.pt
#   inflating: content/scores/box_pred_787.pt
#   inflating: content/scores/box_pred_406.pt
#   inflating: content/scores/box_pred_1959.pt
#   inflating: content/scores/box_pred_2056.pt
#   inflating: content/scores/box_pred_179.pt
#   inflating: content/scores/box_pred_654.pt
#   inflating: content/scores/box_pred_1213.pt
#   inflating: content/scores/box_pred_2887.pt
#   inflating: content/scores/box_pred_2727.pt
#   inflating: content/scores/box_pred_1536.pt
#   inflating: content/scores/box_pred_2871.pt
#   inflating: content/scores/box_pred_927.pt
#   inflating: content/scores/box_pred_1574.pt
#   inflating: content/scores/box_pred_1625.pt
#   inflating: content/scores/box_pred_3115.pt
#   inflating: content/scores/box_pred_199.pt
#   inflating: content/scores/box_pred_3126.pt
#   inflating: content/scores/box_pred_2517.pt
#   inflating: content/scores/box_pred_3213.pt
#   inflating: content/scores/box_pred_669.pt
#   inflating: content/scores/box_pred_1413.pt
#   inflating: content/scores/box_pred_713.pt
#   inflating: content/scores/box_pred_2321.pt
#   inflating: content/scores/box_pred_549.pt
#   inflating: content/scores/box_pred_2559.pt
#   inflating: content/scores/box_pred_640.pt
#   inflating: content/scores/box_pred_1493.pt
#   inflating: content/scores/box_pred_3235.pt
#   inflating: content/scores/box_pred_2908.pt
#   inflating: content/scores/box_pred_2096.pt
#   inflating: content/scores/box_pred_2006.pt
#   inflating: content/scores/box_pred_1750.pt
#   inflating: content/scores/box_pred_744.pt
#   inflating: content/scores/box_pred_1460.pt
#   inflating: content/scores/box_pred_968.pt
#   inflating: content/scores/box_pred_2822.pt
#   inflating: content/scores/box_pred_3087.pt
#   inflating: content/scores/box_pred_632.pt
#   inflating: content/scores/box_pred_3216.pt
#   inflating: content/scores/box_pred_687.pt
#   inflating: content/scores/box_pred_306.pt
#   inflating: content/scores/box_pred_1740.pt
#   inflating: content/scores/box_pred_320.pt
#   inflating: content/scores/box_pred_571.pt
#   inflating: content/scores/box_pred_144.pt
#   inflating: content/scores/box_pred_2304.pt
#   inflating: content/scores/box_pred_3233.pt
#   inflating: content/scores/box_pred_1840.pt
#   inflating: content/scores/box_pred_1721.pt
#   inflating: content/scores/box_pred_2870.pt
#   inflating: content/scores/box_pred_627.pt
#   inflating: content/scores/box_pred_2646.pt
#   inflating: content/scores/box_pred_2550.pt
#   inflating: content/scores/box_pred_722.pt
#   inflating: content/scores/box_pred_115.pt
#   inflating: content/scores/box_pred_1707.pt
#   inflating: content/scores/box_pred_1039.pt
#   inflating: content/scores/box_pred_1787.pt
#   inflating: content/scores/box_pred_2232.pt
#   inflating: content/scores/box_pred_1162.pt
#   inflating: content/scores/box_pred_407.pt
#   inflating: content/scores/box_pred_1880.pt
#   inflating: content/scores/box_pred_2196.pt
#   inflating: content/scores/box_pred_2694.pt
#   inflating: content/scores/box_pred_2714.pt
#   inflating: content/scores/box_pred_1588.pt
#   inflating: content/scores/box_pred_1006.pt
#   inflating: content/scores/box_pred_1422.pt
#   inflating: content/scores/box_pred_1031.pt
#   inflating: content/scores/box_pred_3145.pt
#   inflating: content/scores/box_pred_1468.pt
#   inflating: content/scores/box_pred_2811.pt
#   inflating: content/scores/box_pred_3243.pt
#   inflating: content/scores/box_pred_1089.pt
#   inflating: content/scores/box_pred_585.pt
#   inflating: content/scores/box_pred_388.pt
#   inflating: content/scores/box_pred_3099.pt
#   inflating: content/scores/box_pred_2282.pt
#   inflating: content/scores/box_pred_2927.pt
#   inflating: content/scores/box_pred_427.pt
#   inflating: content/scores/box_pred_2322.pt
#   inflating: content/scores/box_pred_240.pt
#   inflating: content/scores/box_pred_1549.pt
#   inflating: content/scores/box_pred_2139.pt
#   inflating: content/scores/box_pred_972.pt
#   inflating: content/scores/box_pred_2283.pt
#   inflating: content/scores/box_pred_1121.pt
#   inflating: content/scores/box_pred_3142.pt
#   inflating: content/scores/box_pred_2382.pt
#   inflating: content/scores/box_pred_1623.pt
#   inflating: content/scores/box_pred_138.pt
#   inflating: content/scores/box_pred_2879.pt
#   inflating: content/scores/box_pred_1024.pt
#   inflating: content/scores/box_pred_1222.pt
#   inflating: content/scores/box_pred_1077.pt
#   inflating: content/scores/box_pred_3227.pt
#   inflating: content/scores/box_pred_2794.pt
#   inflating: content/scores/box_pred_2111.pt
#   inflating: content/scores/box_pred_478.pt
#   inflating: content/scores/box_pred_2777.pt
#   inflating: content/scores/box_pred_69.pt
#   inflating: content/scores/box_pred_975.pt
#   inflating: content/scores/box_pred_631.pt
#   inflating: content/scores/box_pred_1337.pt
#   inflating: content/scores/box_pred_417.pt
#   inflating: content/scores/box_pred_1592.pt
#   inflating: content/scores/box_pred_2786.pt
#   inflating: content/scores/box_pred_1624.pt
#   inflating: content/scores/box_pred_1611.pt
#   inflating: content/scores/box_pred_362.pt
#   inflating: content/scores/box_pred_1502.pt
#   inflating: content/scores/box_pred_398.pt
#   inflating: content/scores/box_pred_1749.pt
#   inflating: content/scores/box_pred_937.pt
#   inflating: content/scores/box_pred_1733.pt
#   inflating: content/scores/box_pred_2289.pt
#   inflating: content/scores/box_pred_1472.pt
#   inflating: content/scores/box_pred_1461.pt
#   inflating: content/scores/box_pred_2843.pt
#   inflating: content/scores/box_pred_97.pt
#   inflating: content/scores/box_pred_414.pt
#   inflating: content/scores/box_pred_11.pt
#   inflating: content/scores/box_pred_2221.pt
#   inflating: content/scores/box_pred_973.pt
#   inflating: content/scores/box_pred_225.pt
#   inflating: content/scores/box_pred_2527.pt
#   inflating: content/scores/box_pred_690.pt
#   inflating: content/scores/box_pred_3204.pt
#   inflating: content/scores/box_pred_2122.pt
#   inflating: content/scores/box_pred_1396.pt
#   inflating: content/scores/box_pred_1933.pt
#   inflating: content/scores/box_pred_2156.pt
#   inflating: content/scores/box_pred_2834.pt
#   inflating: content/scores/box_pred_2432.pt
#   inflating: content/scores/box_pred_2590.pt
#   inflating: content/scores/box_pred_1264.pt
#   inflating: content/scores/box_pred_493.pt
#   inflating: content/scores/box_pred_2637.pt
#   inflating: content/scores/box_pred_883.pt
#   inflating: content/scores/box_pred_1790.pt
#   inflating: content/scores/box_pred_1362.pt
#   inflating: content/scores/box_pred_576.pt
#   inflating: content/scores/box_pred_68.pt
#   inflating: content/scores/box_pred_1715.pt
#   inflating: content/scores/box_pred_165.pt
#   inflating: content/scores/box_pred_1008.pt
#   inflating: content/scores/box_pred_149.pt
#   inflating: content/scores/box_pred_2846.pt
#   inflating: content/scores/box_pred_2584.pt
#   inflating: content/scores/box_pred_3075.pt
#   inflating: content/scores/box_pred_2801.pt
#   inflating: content/scores/box_pred_1890.pt
#   inflating: content/scores/box_pred_2088.pt
#   inflating: content/scores/box_pred_1494.pt
#   inflating: content/scores/box_pred_1234.pt
#   inflating: content/scores/box_pred_1364.pt
#   inflating: content/scores/box_pred_402.pt
#   inflating: content/scores/box_pred_2157.pt
#   inflating: content/scores/box_pred_220.pt
#   inflating: content/scores/box_pred_3025.pt
#   inflating: content/scores/box_pred_1789.pt
#   inflating: content/scores/box_pred_766.pt
#   inflating: content/scores/box_pred_2487.pt
#   inflating: content/scores/box_pred_1419.pt
#   inflating: content/scores/box_pred_262.pt
#   inflating: content/scores/box_pred_510.pt
#   inflating: content/scores/box_pred_310.pt
#   inflating: content/scores/box_pred_2955.pt
#   inflating: content/scores/box_pred_336.pt
#   inflating: content/scores/box_pred_1792.pt
#   inflating: content/scores/box_pred_1855.pt
#   inflating: content/scores/box_pred_2932.pt
#   inflating: content/scores/box_pred_1239.pt
#   inflating: content/scores/box_pred_2377.pt
#   inflating: content/scores/box_pred_4.pt
#   inflating: content/scores/box_pred_1976.pt
#   inflating: content/scores/box_pred_2498.pt
#   inflating: content/scores/box_pred_2404.pt
#   inflating: content/scores/box_pred_461.pt
#   inflating: content/scores/box_pred_1523.pt
#   inflating: content/scores/box_pred_2579.pt
#   inflating: content/scores/box_pred_2653.pt
#   inflating: content/scores/box_pred_436.pt
#   inflating: content/scores/box_pred_1041.pt
#   inflating: content/scores/box_pred_1324.pt
#   inflating: content/scores/box_pred_1392.pt
#   inflating: content/scores/box_pred_5.pt
#   inflating: content/scores/box_pred_1677.pt
#   inflating: content/scores/box_pred_622.pt
#   inflating: content/scores/box_pred_1847.pt
#   inflating: content/scores/box_pred_1814.pt
#   inflating: content/scores/box_pred_726.pt
#   inflating: content/scores/box_pred_2698.pt
#   inflating: content/scores/box_pred_538.pt
#   inflating: content/scores/box_pred_124.pt
#   inflating: content/scores/box_pred_2224.pt
#   inflating: content/scores/box_pred_2954.pt
#   inflating: content/scores/box_pred_95.pt
#   inflating: content/scores/box_pred_838.pt
#   inflating: content/scores/box_pred_2747.pt
#   inflating: content/scores/box_pred_790.pt
#   inflating: content/scores/box_pred_2885.pt
#   inflating: content/scores/box_pred_2200.pt
#   inflating: content/scores/box_pred_810.pt
#   inflating: content/scores/box_pred_1675.pt
#   inflating: content/scores/box_pred_981.pt
#   inflating: content/scores/box_pred_106.pt
#   inflating: content/scores/box_pred_3228.pt
#   inflating: content/scores/box_pred_3182.pt
#   inflating: content/scores/box_pred_2051.pt
#   inflating: content/scores/box_pred_147.pt
#   inflating: content/scores/box_pred_1615.pt
#   inflating: content/scores/box_pred_2446.pt
#   inflating: content/scores/box_pred_2181.pt
#   inflating: content/scores/box_pred_1342.pt
#   inflating: content/scores/box_pred_2349.pt
#   inflating: content/scores/box_pred_53.pt
#   inflating: content/scores/box_pred_1334.pt
#   inflating: content/scores/box_pred_2084.pt
#   inflating: content/scores/box_pred_1014.pt
#   inflating: content/scores/box_pred_3260.pt
#   inflating: content/scores/box_pred_825.pt
#   inflating: content/scores/box_pred_904.pt
#   inflating: content/scores/box_pred_2424.pt
#   inflating: content/scores/box_pred_577.pt
#   inflating: content/scores/box_pred_2460.pt
#   inflating: content/scores/box_pred_1806.pt
#   inflating: content/scores/box_pred_328.pt
#   inflating: content/scores/box_pred_146.pt
#   inflating: content/scores/box_pred_2702.pt
#   inflating: content/scores/box_pred_2638.pt
#   inflating: content/scores/box_pred_1915.pt
#   inflating: content/scores/box_pred_1516.pt
#   inflating: content/scores/box_pred_630.pt
#   inflating: content/scores/box_pred_43.pt
#   inflating: content/scores/box_pred_2050.pt
#   inflating: content/scores/box_pred_2357.pt
#   inflating: content/scores/box_pred_429.pt
#   inflating: content/scores/box_pred_64.pt
#   inflating: content/scores/box_pred_1874.pt
#   inflating: content/scores/box_pred_2239.pt
#   inflating: content/scores/box_pred_1608.pt
#   inflating: content/scores/box_pred_2516.pt
#   inflating: content/scores/box_pred_16.pt
#   inflating: content/scores/box_pred_2919.pt
#   inflating: content/scores/box_pred_2867.pt
#   inflating: content/scores/box_pred_2153.pt
#   inflating: content/scores/box_pred_1429.pt
#   inflating: content/scores/box_pred_1598.pt
#   inflating: content/scores/box_pred_2210.pt
#   inflating: content/scores/box_pred_2781.pt
#   inflating: content/scores/box_pred_3181.pt
#   inflating: content/scores/box_pred_2392.pt
#   inflating: content/scores/box_pred_206.pt
#   inflating: content/scores/box_pred_462.pt
#   inflating: content/scores/box_pred_964.pt
#   inflating: content/scores/box_pred_1294.pt
#   inflating: content/scores/box_pred_2186.pt
#   inflating: content/scores/box_pred_3089.pt
#   inflating: content/scores/box_pred_1575.pt
#   inflating: content/scores/box_pred_3201.pt
#   inflating: content/scores/box_pred_811.pt
#   inflating: content/scores/box_pred_1699.pt
#   inflating: content/scores/box_pred_1957.pt
#   inflating: content/scores/box_pred_2745.pt
#   inflating: content/scores/box_pred_2076.pt
#   inflating: content/scores/box_pred_198.pt
#   inflating: content/scores/box_pred_814.pt
#   inflating: content/scores/box_pred_667.pt
#   inflating: content/scores/box_pred_1093.pt
#   inflating: content/scores/box_pred_1585.pt
#   inflating: content/scores/box_pred_238.pt
#   inflating: content/scores/box_pred_374.pt
#   inflating: content/scores/box_pred_1311.pt
#   inflating: content/scores/box_pred_523.pt
#   inflating: content/scores/box_pred_127.pt
#   inflating: content/scores/box_pred_2364.pt
#   inflating: content/scores/box_pred_42.pt
#   inflating: content/scores/box_pred_2969.pt
#   inflating: content/scores/box_pred_1989.pt
#   inflating: content/scores/box_pred_2214.pt
#   inflating: content/scores/box_pred_1410.pt
#   inflating: content/scores/box_pred_644.pt
#   inflating: content/scores/box_pred_1050.pt
#   inflating: content/scores/box_pred_3198.pt
#   inflating: content/scores/box_pred_2332.pt
#   inflating: content/scores/box_pred_3090.pt
#   inflating: content/scores/box_pred_1831.pt
#   inflating: content/scores/box_pred_1375.pt

# %%
batch_size = 16
def loss_bce(mask_pred, masks):
    
    l = nn.BCELoss()

    
    loss = l(mask_pred, masks)
     
    # loss = 0.9*loss1 + 1.1*loss2 + 0.8*loss3
    return loss

# %%
# confidence_scores_path = '/content/drive/MyDrive/Mask/boxes/'
# box_preds_path = '/content/drive/MyDrive/Mask/scores/'
# proposal_path = '/content/drive/MyDrive/Mask/proposals/'
confidence_scores_path = '/content/content/scores/'
box_preds_path = '/content/content/boxes/'
proposal_path = '/content/content/proposals/'

# %% [markdown]
# ###Focal Loss (Extra)

# %%
class FocalLoss(nn.Module):
  def __init__(self, gamma=3.0, alpha=None, size_average=True):
      super(FocalLoss, self).__init__()
      self.gamma = gamma
      self.alpha = alpha
      if isinstance(alpha,(float,int)): self.alpha = torch.Tensor([alpha,1-alpha])
      if isinstance(alpha,list): self.alpha = torch.Tensor(alpha)
      self.size_average = size_average

  def forward(self, input, target):
      if input.dim()>2:
          input = input.view(input.size(0),input.size(1),-1)  # N,C,H,W => N,C,H*W
          input = input.transpose(1,2)    # N,C,H*W => N,H*W,C
          input = input.contiguous().view(-1,input.size(2))   # N,H*W,C => N*H*W,C
      target = target.permute((0,2,3,1))
      target = target.reshape(-1, target.shape[3])
      target = target.type(torch.int64)
      # print(target.shape)
      # print(input.shape)
      logpt = F.log_softmax(input)
      logpt = logpt.gather(1,target)
      logpt = logpt.view(-1)
      pt = Variable(logpt.data.exp())

      if self.alpha is not None:
          if self.alpha.type()!=input.data.type():
              self.alpha = self.alpha.type_as(input.data)
          at = self.alpha.gather(0,target.data.view(-1))
          logpt = logpt * Variable(at)

      loss = -1 * (1-pt)**self.gamma * logpt
      if self.size_average: return loss.mean()
      else: return loss.sum()

# %%
criterion = FocalLoss()

# %% [markdown]
# ###MaskHead Definition

# %%
class MaskHead(pl.LightningModule):
  def __init__(self):
    super(MaskHead, self).__init__()
    self.conv1 = nn.Sequential(nn.Conv2d(256, 256, kernel_size=3, padding=1), nn.BatchNorm2d(256))
    self.conv2 = nn.Sequential(nn.Conv2d(256, 256, kernel_size=3, padding=1), nn.BatchNorm2d(256))
    self.conv3 = nn.Sequential(nn.Conv2d(256, 256, kernel_size=3, padding=1), nn.BatchNorm2d(256))
    self.conv4 = nn.Sequential(nn.Conv2d(256, 256, kernel_size=3, padding=1), nn.BatchNorm2d(256))
    self.deconv = nn.ConvTranspose2d(256, 256, kernel_size=2, stride=2) ####
    self.conv6 = nn.Conv2d(256, 3, kernel_size=1)
    self.sigmoid = nn.Sigmoid()
    self.relu = nn.ReLU()

    
    self.train_loss = []
    self.val_loss = []
  

  def forward(self, x):
    x = self.conv1(x)
    x = self.relu(x)
    x = self.conv2(x)
    x = self.relu(x)
    x = self.conv3(x)
    x = self.relu(x)
    x = self.conv4(x)
    x = self.relu(x)
    x = self.deconv(x)
    x = self.relu(x)
    x = self.conv6(x)
    x = self.sigmoid(x) ### Shivani clarify 

    return x
  
  # This function for each proposal finds the appropriate feature map to sample and using RoIAlign it samples
  # a (256,P,P) feature map. This feature map is then flattened into a (256*P*P) vector
  # Input:
  #      fpn_feat_list: list:len(FPN){(bz,256,H_feat,W_feat)}
  #      proposals: list:len(bz){(per_image_proposals,4)} ([x1,y1,x2,y2] format)
  #      P: scalar
  # Output:
  #      feature_vectors: (total_proposals, 256*P*P)  (make sure the ordering of the proposals are the same as the ground truth creation) 
  def MultiScaleRoiAlign(self, fpn_feat_list,proposals,P=14):

        image_size = (800, 1088) # (h, w)
        feature_vectors = []

        num_proposals = len(proposals)
        for i in range(num_proposals):
            cur_proposal = proposals[i]
            feature_vectors_ = []
            for j in range(cur_proposal.shape[0]):
              width = cur_proposal[j][2] - cur_proposal[j][0]
              height = cur_proposal[j][3] - cur_proposal[j][1]
              K = torch.clip(torch.floor( 4 + torch.log2(torch.sqrt(width*height)/224)),2,5).int()
          
              box = cur_proposal[j].clone()
              scale_x = image_size[1]/fpn_feat_list[K-2].shape[3]
              scale_y = image_size[0]/fpn_feat_list[K-2].shape[2]

              box = box.reshape(1,-1)
              box[:,0] = box[:,0] / scale_x
              box[:,1] = box[:,1] / scale_y 
              box[:,2] = box[:,2] / scale_x
              box[:,3] = box[:,3] / scale_y
            
              feature_map = fpn_feat_list[K-2][i].unsqueeze(0) 
              aligned_box_map  = torchvision.ops.roi_align(feature_map, [box], output_size=P, spatial_scale=1, sampling_ratio=-1)
              # aligned_box_map = aligned_box_map.flatten()
              # print(aligned_box_map.shape)
              feature_vectors_.append(aligned_box_map)
        
            feature_vectors_ = torch.cat(feature_vectors_, dim=0)
            # print('feature_vectors_.shape: ',feature_vectors_.shape)
            # print(feature_vectors_.unsqueeze(0).shape)
            feature_vectors.append(feature_vectors_.unsqueeze(0))

        feature_vectors = torch.cat(feature_vectors, dim=0)
        # print('feature_vectors.shape:', feature_vectors.shape)
        return feature_vectors
      

  def training_step(self, batch, batch_idx):
      images, labels, masks, bboxes, indices = batch
      images = images.to(device)
      backout = backbone(images)
      masks = list(masks)
      # print(len(masks))
      
      # # # The RPN implementation takes as first argument the following image list
      # im_lis = ImageList(images, [(800, 1088)]*images.shape[0])
      # # # Then we pass the image list and the backbone output through the rpn
      # rpnout = rpn(im_lis, backout)
      # # # print(rpnout[0])
      # proposals=[proposal[0:keep_topK,:] for proposal in rpnout[0]]
      # # # A list of features produces by the backbone's FPN levels: list:len(FPN){(bz,256,H_feat,W_feat)}
      fpn_feat_list= list(backout.values())

      # # # print(fpn_feat_list.)
      # feature_vectors = boxhead.MultiScaleRoiAlign(fpn_feat_list, proposals)
      # # # print(feature_vectors.shape)

      # # _, regressor_targets = boxhead.create_ground_truth(proposals, labels, bboxes)
      # # # labels, regressor_target = labels[:keep_topK], regressor_target[:keep_topK]
      # class_logits, box_preds = boxhead.forward(feature_vectors)
      running_loss = 0
      for idx_num, idx in enumerate(indices):
        proposals = [torch.load(proposal_path + 'prop_pred_' + str(idx) + '.pt')]
        class_logits = torch.load(confidence_scores_path + 'cls_logit_' + str(idx) + '.pt')
        box_preds = torch.load(box_preds_path + 'box_pred_' + str(idx) + '.pt')
        # print(box_preds.shape)
        boxes = []
        # scores = []
        # labels = []
        # for i, proposal in enumerate(proposals):
        #   class_logit = class_logits[i*keep_topK: i*keep_topK + keep_topK]
        #   box_pred = box_preds[i*keep_topK: i*keep_topK + keep_topK]
        #   box, score, _ = self.postprocess_detections(images.squeeze(0), class_logits = class_logit, box_regression = box_pred, proposals = proposal, conf_thresh = 0.8, keep_num_preNMS=500, keep_num_postNMS=100)
          
        #   boxes.append(box)

        # print(len(box))
        # print(box_preds)
        boxes, scores, labels = boxhead.postprocess_detections(class_logits, box_preds, proposals, keep_num_postNMS=50)
        boxes = [box.to(device) for box in boxes]
        feature_vectors_2 = self.MultiScaleRoiAlign(fpn_feat_list, boxes) 

        fv2_shape = feature_vectors_2.shape
        # print(fv2_shape)
        # feature_vectors_2 = feature_vectors_2.reshape((fv2_shape[0]*fv2_shape[1], fv2_shape[2], fv2_shape[3], fv2_shape[4]))
        mask_pred = self.forward(feature_vectors_2.squeeze(0))
        

        mp_shape = mask_pred.shape
        # mask_pred = mask_pred.reshape((batch_size, int(mp_shape[0]/batch_size), mp_shape[1], mp_shape[2], mp_shape[3]))
        if mask_pred.shape[0] < masks[idx_num].shape[0]:                # result of keep might be <100
              mask_target = mask_target[:masks[idx_num].shape[0]]
        ind = torch.tensor(np.indices(labels[0].unsqueeze(1).shape))
        # print(labels[0])
        ind[-1] = labels[0].unsqueeze(1) - 1
        mask_pred = mask_pred[tuple(ind)]
        masks_ = masks[idx_num][tuple(ind)]
        # print(mask_pred.shape)
        idx12 = labels[0].unsqueeze(1) > 0
        mask_pred = mask_pred[idx12]
        # print(mask_pred.shape)
        # print(idx12)
        masks_ = masks_[idx12]
        # print(masks.shape)
        # masks = 
        # print(len(masks))
        # loss_bce = nn.BCELoss()
        if mask_pred.shape[0]==0:
          running_loss += 0
        else: 
          running_loss += loss_bce(mask_pred, masks_)
        # loss = criterion(mask_pred, masks[0])

      return {"loss": running_loss/batch_size}

  def training_epoch_end(self, outputs):
      self.train_loss.append((torch.tensor([output['loss'] for output in outputs]).mean().item()))

  def validation_step(self, batch, batch_idx):
      images, labels, masks, bboxes, indices = batch
      images = images.to(device)
      backout = backbone(images)
      masks = torch.stack(list(masks))

      # The RPN implementation takes as first argument the following image list
      # im_lis = ImageList(images, [(800, 1088)]*images.shape[0])
      # # Then we pass the image list and the backbone output through the rpn
      # # keep_topK = 20
      # rpnout = rpn(im_lis, backout)
      # proposals=[proposal[0:keep_topK,:] for proposal in rpnout[0]]
      # # A list of features produces by the backbone's FPN levels: list:len(FPN){(bz,256,H_feat,W_feat)}
      fpn_feat_list= list(backout.values())

      # feature_vectors = boxhead.MultiScaleRoiAlign(fpn_feat_list, proposals)

      # labels, regressor_targets = boxhead.create_ground_truth(proposals, labels, bboxes)
      # # labels, regressor_target = labels[:keep_topK], regressor_target[:keep_topK]
      # class_logits, box_preds = boxhead.forward(feature_vectors)

      running_loss = 0
      for idx_num, idx in enumerate(indices):
        proposals = [torch.load(proposal_path + 'prop_pred_' + str(idx) + '.pt')]
        class_logits = torch.load(confidence_scores_path + 'cls_logit_' + str(idx) + '.pt')
        box_preds = torch.load(box_preds_path + 'box_pred_' + str(idx) + '.pt')
        
        boxes = []
        # scores = []
        # # labels = []
        # for i, proposal in enumerate(proposals):
        #   class_logit = class_logits[i*keep_topK: i*keep_topK + keep_topK]
        #   box_pred = box_preds[i*keep_topK: i*keep_topK + keep_topK]
        #   box, score, _ = self.postprocess_detections(images.squeeze(0), class_logits = class_logit, box_regression = box_pred, proposals = proposal, conf_thresh = 0.8, keep_num_preNMS=500, keep_num_postNMS=100)
          
        #   boxes.append(box)
        box_preds = box_preds.to(device)
        boxes, scores, labels = boxhead.postprocess_detections(class_logits, box_preds, proposals, keep_num_postNMS=50)
        boxes = [box.to(device) for box in boxes]
        
        feature_vectors_2 = self.MultiScaleRoiAlign(fpn_feat_list, boxes)
        fv2_shape = feature_vectors_2.shape
        # feature_vectors_2 = feature_vectors_2.reshape((fv2_shape[0]*fv2_shape[1], fv2_shape[2], fv2_shape[3], fv2_shape[4]))
        mask_pred =  self.forward(feature_vectors_2.squeeze(0))
        if mask_pred.shape[0] < masks[idx_num].shape[0]:                # result of keep might be <100
              mask_target = mask_target[:masks[idx_num].shape[0]]
        mp_shape = mask_pred.shape
        ind = torch.tensor(np.indices(labels[0].unsqueeze(1).shape))
        
        ind[-1] = labels[0].unsqueeze(1) - 1
        mask_pred = mask_pred[tuple(ind)]
        masks_ = masks[idx_num][tuple(ind)]
        # print(mask_pred.shape)
        idx12 = labels[0].unsqueeze(1) > 0
        mask_pred = mask_pred[idx12]
        # print(mask_pred.shape)
        
        masks_ = masks_[idx12]
        # print(masks.shape)
        # mask_pred = mask_pred.reshape((batch_size, int(mp_shape[0]/batch_size), mp_shape[1], mp_shape[2], mp_shape[3]))
        if mask_pred.shape[0]==0:
          running_loss += 0
        else: 
          running_loss += loss_bce(mask_pred, masks_)
        # loss = criterion(mask_pred, masks[0])

      return {"loss": running_loss/batch_size}

  def validation_epoch_end(self, outputs):
      self.val_loss.append((torch.tensor([output['loss'] for output in outputs]).mean().item()))


  def configure_optimizers(self):
      # optimizer = torch.optim.SGD(self.parameters(), lr=0.001, weight_decay = 5e-4)
      optimizer = torch.optim.Adam(self.parameters(), lr=0.0001, weight_decay=0.0001)
      scheduler = {"scheduler": torch.optim.lr_scheduler.MultiStepLR(optimizer, [11, 18, 25, 30], gamma=0.1)}
      # scheduler = {"scheduler": torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[20, 30], gamma=0.1)}
      return {"optimizer": optimizer, 'lr_scheduler': scheduler}

  def postprocess_detections(self, decoded_image, class_logits, box_regression, proposals, conf_thresh=0.8, keep_num_preNMS=100, keep_num_postNMS=50, plot_ = False): 

    class_scores, class_labels = torch.max(class_logits, dim =1)

    valid_indices = class_labels > 0

    proposals = proposals[valid_indices]
    box_regression = box_regression[valid_indices]
    class_labels = class_labels[valid_indices]
    class_scores = class_scores[valid_indices]
    

    boxes = torch.zeros((len(class_labels), 4))
    for i in range(len(class_labels)):
      boxes[i,:] = box_regression[i, (class_labels[i]-1)*4:class_labels[i]*4 ]
    boxes = flattened_output_decoding(boxes, proposals)

    boxes[boxes[:,2] > 1088, 2] = 1088
    boxes[boxes[:,3] > 800, 3] = 800
    boxes[boxes[:,0] < 0, 0] = 0
    boxes[boxes[:,1] < 0, 1] = 0

    keep = torch.tensor([]).to(device)
    for i in range(1, 4):
        regout_per_cls = regout_decoded[:, i]                   # [sampled_rpns, 4]
        regout_positive = torch.where(regout_per_cls[:, 0] > -1)
        boxes_per_cls = regout_per_cls[regout_positive[0]]      # [N, 4]
        scores_per_cls = cls_out[:, i]
        scores_per_cls = scores_per_cls[regout_positive[0]]

        # Apply nms for each class
        keep_idx = ops.nms(boxes_per_cls, scores_per_cls, 0.5)

        keep_boxes = boxes_per_cls[keep_idx]
        keep_scores = scores_per_cls[keep_idx]
        keep_box_score = torch.cat((keep_boxes, keep_scores.unsqueeze(-1)), dim=-1)   # [N_nms, 5]
  
        cls = torch.tensor([[i]]).type(torch.float).to(device)
        cls = cls.expand_as(keep_scores.unsqueeze(-1))
        keep_cls = torch.cat((keep_box_score, cls), dim=-1)     # [N_nms, 6] as [x1,y1,x2,y2,score,class]
        keep = torch.cat((keep, keep_cls), dim=0)
        
    # The maximum detections combined for all classes in a image
    # Find the top 100 boxes with scores
    _, idx_sorted = torch.sort(keep[:, 4], descending=True)
    keep_sorted = keep[idx_sorted]
    keep_top100 = keep_sorted[:100]
   


    # print(class_scores.shape)
    sorted_scores, sorted_indices = torch.sort(class_scores, descending = True) 

    keep_num_preNMS = min(keep_num_preNMS, len(sorted_scores))
    pre_nms_indices = sorted_indices[0:keep_num_preNMS]
    pre_nms_scores = sorted_scores[0:keep_num_preNMS] 
    boxes = boxes[pre_nms_indices,:]
    class_labels = class_labels[pre_nms_indices]
    # print(boxes.shape)
    # print(pre_nms_scores.shape)
    boxes = boxes.to(device)

    inds = torchvision.ops.nms(boxes, pre_nms_scores, 0.5)

    boxes = boxes[inds]
    # print(boxes.shape)
    
    # boxes = boxes.detach().numpy()
    return boxes, pre_nms_scores, class_labels

# %% [markdown]
# ###Loading any trained model

# %%
model = MaskHead() 
# model = MaskHead.load_from_checkpoint('/content/epoch=21-step=53878.ckpt')
model.to(device)
keep_topK=500
box_weights = torch.load('/content/maskhead_bce_n_.pth')
model.load_state_dict(box_weights)
model.eval()
# Out:
# MaskHead(
#   (conv1): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#   (conv6): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#   (sigmoid): Sigmoid()
#   (relu): ReLU()
# )

# %% [markdown]
# ###MaskHead Training

# %%
model = MaskHead()
model.to(device)
keep_topK=500
trainer = pl.Trainer(max_epochs=30, gpus=1, num_sanity_val_steps=0, default_root_dir="/content/ckpts/")
trainer.fit(model, COCODataLoader)
torch.save(model.state_dict(), 'maskhead_bce_n_.pth')
# Out:
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:441: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   rank_zero_deprecation(
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name    | Type            | Params
# --------------------------------------------
# 0 | conv1   | Sequential      | 590 K
# 1 | conv2   | Sequential      | 590 K
# 2 | conv3   | Sequential      | 590 K
# 3 | conv4   | Sequential      | 590 K
# 4 | deconv  | ConvTranspose2d | 262 K
# 5 | conv6   | Conv2d          | 771
# 6 | sigmoid | Sigmoid         | 0
# 7 | relu    | ReLU            | 0
# --------------------------------------------
# 2.6 M     Trainable params
# 0         Non-trainable params
# 2.6 M     Total params
# 10.502    Total estimated model params size (MB)
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 12 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:488: PossibleUserWarning: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test/predict dataloaders.
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 12 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=30` reached.

# %%
model.train_loss
# Out:
# [0.5706157684326172,
#  0.5402987003326416,
#  0.5339582562446594,
#  0.5321882963180542,
#  0.5310494303703308,
#  0.5301476120948792,
#  0.5289710164070129,
#  0.5294167399406433,
#  0.5282508730888367,
#  0.5265479683876038,
#  0.526225209236145,
#  0.5234083533287048,
#  0.5222313404083252,
#  0.5213072896003723,
#  0.521565318107605,
#  0.5215277075767517,
#  0.520297110080719,
#  0.5204072594642639,
#  0.5203791856765747,
#  0.5192059874534607,
#  0.5194277763366699,
#  0.5192421674728394,
#  0.5193824768066406,
#  0.5196021795272827,
#  0.5187771320343018,
#  0.518444836139679,
#  0.5194950103759766,
#  0.5193286538124084,
#  0.5190631747245789,
#  0.5191900730133057]

# %%
# train_losses = np.load("train_losses.npy")
# # validation_losses = np.load("val_losses.npy")

plt.figure()
epochs = np.arange(30)
plt.plot(epochs,  model.train_loss, label = 'Train')
plt.plot(epochs,  model.val_loss, label = 'Val')
plt.title('Loss curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
COCODataLoader.setup()
test_loader = COCODataLoader.predict_dataloader()

# %% [markdown]
# ###Visualising Masks and mAP calculation

# %%
def apply_mask(image, mask, color, alpha=0.5):
    """Apply the given mask to the image.
    """
    for c in range(3):
        image[:, :, c] = np.where(mask == 1,
                                  image[:, :, c] *
                                  (1 - alpha) + alpha * color[c] * 255,
                                  image[:, :, c])
    return image

# %%
def display_instance(data, plt, scores=None, masks=None, labels=None, image=None, boxes=None):
    '''
    data: 1*{'image', 'target'}
    masks: [100, 800, 1088]
    '''
    if data:
        image = data['image'].numpy()
        image = np.transpose(image, (1, 2, 0))
        boxes = data['target']['bbox'].numpy()
        masks = data['target']['mask'].numpy() 
        labels = data['target']['label'].numpy()

    else:
        image = np.transpose(image.detach().cpu().numpy(), (1, 2, 0))
        boxes = boxes.detach().cpu().numpy()
        masks = masks.detach().cpu().numpy()
        labels = labels.detach().cpu().numpy()
    
    class_names = {1: "vehicle", 2: 'people', 3: 'animal'}
    
    # Number of instances
    N = boxes.shape[0]
    if not N:
        print("\n*** No instances to display *** \n")
    else:
        assert boxes.shape[0] == masks.shape[0] == labels.shape[0]

    # Generate random colors
    # colors = random_colors(N)

    image_convert = (image - image.min()) * (1/(image.max() - image.min()) * 255)
    masked_image = image_convert.astype(np.uint32).copy()

    # Plot bounding boxes
    for i in range(N):
        # color = colors[i]
        # print(color)
        # Bounding box
        x1, y1, x2, y2 = boxes[i,:]
        w = x2 - x1
        h = y2 - y1

        if labels[i] == 1:    # vehicles
            # continue
            color_box = 'r'
            color = (1.0,0.0,0.0)
        elif labels[i] == 2:
            color_box = 'g'
            color = (0.0,1.0,0.0)
            # elif labels[i] == 2:  # people
            #     color_box = 'b'  
        elif labels[i] == 3:  # animals
            color_box = 'b'
            color = (0.0,0.0,1.0)

        ax = plt.gca()
        rect = patches.Rectangle((x1,y1),w,h,linewidth=2,edgecolor=color_box,facecolor='none')
        ax.add_patch(rect)

        # Label
        label = labels[i]
        score = scores[i] if scores is not None else None
        label_name = class_names[label]
        # caption = "{} {:.3f}".format(label_name, score) if score else label_name
        # ax.text(x1, y1, caption, color='w', size=12, backgroundcolor="black")
        # ax.text(x1, y1, caption,
        #         color='w', size=12, backgroundcolor="b")


        # Mask
        mask = masks[i].astype(np.uint32)
        masked_image = apply_mask(masked_image, mask, color)

        ax.imshow(masked_image.astype(np.uint8))
    
    plt.show()

# %%
model.to(device) 
model.eval()
masks_out = []
labels_out = []

mask_tar = []
labels_tar = []
preds = []
targets = []

for j, batch in enumerate(train_loader):
  if j == j:
    if j == j:
      
      
      images, labels_ori, masks, bboxes, indices, old_mask = batch
      labels_ori = torch.Tensor(labels_ori[0])
      # print(old_mask[0].shape)
      print(j)
      # images = (images.unsqueeze(0)).to(device)
      
      images = images.to(device)
      # images = torch.FloatTensor(images)
      # backbone = backbone.double()
      # rpn = rpn.double()
      # boxhead = boxhead.double()
      backout = backbone(images)

      # The RPN implementation takes as first argument the following image list
      im_lis = ImageList(images, [(800, 1088)]*images.shape[0])
      # Then we pass the image list and the backbone output through the rpn
      rpnout = rpn(im_lis, backout)
      proposals=[proposal[0:keep_topK,:] for proposal in rpnout[0]]
      # A list of features produces by the backbone's FPN levels: list:len(FPN){(bz,256,H_feat,W_feat)}
      fpn_feat_list= list(backout.values())

      feature_vectors = boxhead.MultiScaleRoiAlign(fpn_feat_list, proposals)

      # labels, regressor_targets = boxhead.create_ground_truth(proposals, labels, bboxes)

      class_logits, box_preds = boxhead.forward(feature_vectors)


      MEAN = torch.tensor([0.485, 0.456, 0.406])
      STD = torch.tensor([0.229, 0.224, 0.225])

      images = images.cpu().squeeze()

      x = images * STD[:, None, None] + MEAN[:, None, None]

      

      resize = transforms.Resize((800, 1088))
      
      for idx in indices:
            # proposals = [torch.load(proposal_path + 'prop_pred_' + str(idx) + '.pt')]
            # class_logits = torch.load(confidence_scores_path + 'cls_logit_' + str(idx) + '.pt')
            # box_preds = torch.load(box_preds_path + 'box_pred_' + str(idx) + '.pt')
            # print(box_preds.shape)
            boxes = []
            # scores = []
            # labels = []
            # for i, proposal in enumerate(proposals):
            #   class_logit = class_logits[i*keep_topK: i*keep_topK + keep_topK]
            #   box_pred = box_preds[i*keep_topK: i*keep_topK + keep_topK]
            #   box, score, _ = self.postprocess_detections(images.squeeze(0), class_logits = class_logit, box_regression = box_pred, proposals = proposal, conf_thresh = 0.8, keep_num_preNMS=500, keep_num_postNMS=100)
              
            #   boxes.append(box)

            # print(len(box))
            # print(box_preds)
            boxes, scores, labels = boxhead.postprocess_detections(class_logits, box_preds, proposals, keep_num_postNMS=50)
            boxes = [box.to(device) for box in boxes]
            feature_vectors_2 = model.MultiScaleRoiAlign(fpn_feat_list, boxes) 

            fv2_shape = feature_vectors_2.shape
            # print(fv2_shape)
            # feature_vectors_2 = feature_vectors_2.reshape((fv2_shape[0]*fv2_shape[1], fv2_shape[2], fv2_shape[3], fv2_shape[4]))
            mask_pred = model.forward(feature_vectors_2.squeeze(0))
            boxes = boxes[0]
            num_plot = 1
            # print(labels[0])
            cls_lab = labels[0][num_plot-1].item()-1
            mask_one_cls = mask_pred[:,cls_lab,:,:].unsqueeze(1)
            mask_total = torch.tensor([]).to(device)
            for idx in range(mask_pred.shape[0]):

              
              x1, y1, x2, y2 = tuple(boxes[idx].detach().cpu().numpy()) # x1, x2, y1, y2
              x1, y1, x2, y2 = max(0, int(x1)), max(0, int(y1)), min(int(x2), 1088), min(int(y2), 800)
              h = y2 - y1
              w = x2 - x1
              if int(h) < 2 or int(w) < 2:
                  continue
              mask_one = mask_one_cls[idx].unsqueeze(0)               # [1, 1, 28, 28]
              mask_rescaled = F.interpolate(mask_one, size = (h, w), mode='bilinear', align_corners=True).squeeze()   # [h, w]

              # Padding
              p2d = (int(x1), 1088-int(x1)-int(w), int(y1), 800-int(y1)-int(h))
              # print(p2d)
              mask_padded = F.pad(mask_rescaled, p2d).unsqueeze(0)    # [800, 1088]
              mask_total = torch.cat((mask_total,mask_padded), dim=0)
            threshold = 0.5
            positive_idx = torch.where(mask_total >= threshold)
            negative_idx = torch.where(mask_total < threshold)
            mask_total[positive_idx] = 1
            mask_total[negative_idx] = 0
            # print(torch.where(mask_total[1]==1))
            plt.figure(j)
            # print(scores[0])  

            if labels[0][0]!=labels[0][1] and labels[0][1] != 0 and labels[0][0]!=0:
              num_plot = 2    
            # print(labels[0])
            if labels[0][0]!=0:
              pred_image_dict = {'masks':mask_total[:num_plot].detach().cpu().type(torch.uint8),
                            'labels':labels[0][:num_plot].detach().cpu(),
                            'scores':scores[0][:num_plot].detach().cpu()}
              preds.append(pred_image_dict)
              target_dict = {'masks':old_mask[0][:num_plot].detach().cpu().type(torch.uint8),
                            'labels':labels_ori[:num_plot].detach().cpu()}
              targets.append(target_dict)
            # masks_out.append(mask_total[:num_plot].detach().cpu())
            # labels_out.append(labels[0][:num_plot].detach().cpu())
            # mask_tar.append(old_mask[0][:num_plot].detach().cpu())
            # labels_tar.append(labels_ori[:num_plot].detach().cpu())
            display_instance(None, plt, scores[0][:num_plot], mask_total[:num_plot], labels[0][:num_plot], images, boxes[:num_plot])
    
          
      # break

# %%
def apply_mask(image, mask, color, alpha=0.5):
    """Apply the given mask to the image.
    """
    for c in range(3):
        image[:, :, c] = np.where(mask == 1,
                                  image[:, :, c] *
                                  (1 - alpha) + alpha * color[c] * 255,
                                  image[:, :, c])
    return image

# %%
def display_instance(data, plt, scores=None, masks=None, labels=None, image=None, boxes=None):
    '''
    data: 1*{'image', 'target'}
    masks: [100, 800, 1088]
    '''
    if data:
        image = data['image'].numpy()
        image = np.transpose(image, (1, 2, 0))
        boxes = data['target']['bbox'].numpy()
        masks = data['target']['mask'].numpy() 
        labels = data['target']['label'].numpy()

    else:
        image = np.transpose(image.detach().cpu().numpy(), (1, 2, 0))
        boxes = boxes.detach().cpu().numpy()
        masks = masks.detach().cpu().numpy()
        labels = labels.detach().cpu().numpy()
    
    class_names = {1: "vehicle", 2: 'people', 3: 'animal'}
    
    # Number of instances
    N = boxes.shape[0]
    if not N:
        print("\n*** No instances to display *** \n")
    else:
        assert boxes.shape[0] == masks.shape[0] == labels.shape[0]

    # Generate random colors
    # colors = random_colors(N)

    image_convert = (image - image.min()) * (1/(image.max() - image.min()) * 255)
    masked_image = image_convert.astype(np.uint32).copy()

    # Plot bounding boxes
    for i in range(N):
        # color = colors[i]
        # print(color)
        # Bounding box
        x1, y1, x2, y2 = boxes[i,:]
        w = x2 - x1
        h = y2 - y1

        if labels[i] == 1:    # vehicles
            # continue
            color_box = 'r'
            color = (1.0,0.0,0.0)
        elif labels[i] == 2:
            color_box = 'g'
            color = (0.0,1.0,0.0)
            # elif labels[i] == 2:  # people
            #     color_box = 'b'  
        elif labels[i] == 3:  # animals
            color_box = 'b'
            color = (0.0,0.0,1.0)

        ax = plt.gca()
        rect = patches.Rectangle((x1,y1),w,h,linewidth=2,edgecolor=color_box,facecolor='none')
        ax.add_patch(rect)

        # Label
        label = labels[i]
        score = scores[i] if scores is not None else None
        label_name = class_names[label]
        # caption = "{} {:.3f}".format(label_name, score) if score else label_name
        # ax.text(x1, y1, caption, color='w', size=12, backgroundcolor="black")
        # ax.text(x1, y1, caption,
        #         color='w', size=12, backgroundcolor="b")


        # Mask
        mask = masks[i].astype(np.uint32)
        masked_image = apply_mask(masked_image, mask, color)

        ax.imshow(masked_image.astype(np.uint8))
    
    plt.show()

# %%
from torchmetrics.detection.mean_ap import MeanAveragePrecision

# preds = [
#   dict(
#     masks=torch.tensor([[258.0, 41.0, 606.0, 285.0]]),
#     scores=torch.tensor([0.536]),
#     labels=torch.tensor([0]),
#   )
# ]
# target = [dict(boxes=torch.tensor([[214.0, 41.0, 562.0, 285.0]]), labels=torch.tensor([0]),)]
metric = MeanAveragePrecision(iou_type='segm', class_metrics=True, iou_thresholds = [0.5])
metric.update(preds, targets)
from pprint import pprint
pprint(metric.compute())
# Out:
# {'map': tensor(0.6727),
#  'map_50': tensor(0.6727),
#  'map_75': tensor(-1),
#  'map_large': tensor(0.6791),
#  'map_medium': tensor(0.4185),
#  'map_per_class': tensor([0.5912, 0.6873, 0.7396]),
#  'map_small': tensor(-1.),
#  'mar_1': tensor(0.7634),
#  'mar_10': tensor(0.7634),
#  'mar_100': tensor(0.7634),
#  'mar_100_per_class': tensor([0.6910, 0.7663, 0.8329]),
#  'mar_large': tensor(0.7719),
#  'mar_medium': tensor(0.5093),
#  'mar_small': tensor(-1.)}

# %% [markdown]
# ###Real Time Segmentation

# %%
import PIL
import io

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode, b64encode
import cv2
import numpy as np

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  img = js_to_image(data)
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename, img

# %%
def js_to_image(js_reply):
  
  image_bytes = b64decode(js_reply.split(',')[1])
  
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

# %%
def video_stream():
  js = Javascript('''
    var video;
    var div = null;
    var stream;
    var captureCanvas;
    var imgElement;
    var labelElement;
    
    var pendingResolve = null;
    var shutdown = false;
    
    function removeDom() {
       stream.getVideoTracks()[0].stop();
       video.remove();
       div.remove();
       video = null;
       div = null;
       stream = null;
       imgElement = null;
       captureCanvas = null;
       labelElement = null;
    }
    
    function onAnimationFrame() {
      if (!shutdown) {
        window.requestAnimationFrame(onAnimationFrame);
      }
      if (pendingResolve) {
        var result = "";
        if (!shutdown) {
          captureCanvas.getContext('2d').drawImage(video, 0, 0, 640, 480);
          result = captureCanvas.toDataURL('image/jpeg', 0.8)
        }
        var lp = pendingResolve;
        pendingResolve = null;
        lp(result);
      }
    }
    
    async function createDom() {
      if (div !== null) {
        return stream;
      }

      div = document.createElement('div');
      div.style.border = '2px solid black';
      div.style.padding = '3px';
      div.style.width = '100%';
      div.style.maxWidth = '600px';
      document.body.appendChild(div);
      
      const modelOut = document.createElement('div');
      modelOut.innerHTML = "<span>Status:</span>";
      labelElement = document.createElement('span');
      labelElement.innerText = 'No data';
      labelElement.style.fontWeight = 'bold';
      modelOut.appendChild(labelElement);
      div.appendChild(modelOut);
           
      video = document.createElement('video');
      video.style.display = 'block';
      video.width = div.clientWidth - 6;
      video.setAttribute('playsinline', '');
      video.onclick = () => { shutdown = true; };
      stream = await navigator.mediaDevices.getUserMedia(
          {video: { facingMode: "environment"}});
      div.appendChild(video);

      imgElement = document.createElement('img');
      imgElement.style.position = 'absolute';
      imgElement.style.zIndex = 1;
      imgElement.onclick = () => { shutdown = true; };
      div.appendChild(imgElement);
      
      const instruction = document.createElement('div');
      instruction.innerHTML = 
          '<span style="color: red; font-weight: bold;">' +
          'When finished, click here or on the video to stop this demo</span>';
      div.appendChild(instruction);
      instruction.onclick = () => { shutdown = true; };
      
      video.srcObject = stream;
      await video.play();

      captureCanvas = document.createElement('canvas');
      captureCanvas.width = 640; //video.videoWidth;
      captureCanvas.height = 480; //video.videoHeight;
      window.requestAnimationFrame(onAnimationFrame);
      
      return stream;
    }
    async function stream_frame(label, imgData) {
      if (shutdown) {
        removeDom();
        shutdown = false;
        return '';
      }

      var preCreate = Date.now();
      stream = await createDom();
      
      var preShow = Date.now();
      if (label != "") {
        labelElement.innerHTML = label;
      }
            
      if (imgData != "") {
        var videoRect = video.getClientRects()[0];
        imgElement.style.top = videoRect.top + "px";
        imgElement.style.left = videoRect.left + "px";
        imgElement.style.width = videoRect.width + "px";
        imgElement.style.height = videoRect.height + "px";
        imgElement.src = imgData;
      }
      
      var preCapture = Date.now();
      var result = await new Promise(function(resolve, reject) {
        pendingResolve = resolve;
      });
      shutdown = false;
      
      return {'create': preShow - preCreate, 
              'show': preCapture - preShow, 
              'capture': Date.now() - preCapture,
              'img': result};
    }
    ''')

  display(js)
  
def video_frame(label, mask):
  data = eval_js('stream_frame("{}", "{}")'.format(label, mask))
  return data

# %%
keep_topK = 500

# %%
video_stream()
# label for video
label_html = 'Capturing...'
# initialze bounding box to empty
bbox = ''
mask = ''
count = 0 
while True:
    js_reply = video_frame(label_html, mask)
    if not js_reply:
        break

    # convert JS response to OpenCV Image
    frame = js_to_image(js_reply["img"])
    img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    img_resized = cv2.resize(img_rgb, (1088, 800),
                                  interpolation=cv2.INTER_LINEAR)
    image = img_resized.astype('uint8')
    # label = self.labels[idx].astype('float32')
    # mask = torch.tensor(self.masks[idx].astype('float64'))
    # bbox = self.bboxes[idx].astype('float32')
    bbox_array = np.zeros([480,640,4], dtype=np.uint8)
    img_height, img_width, _ = frame.shape
    width_ratio = img_width/1088
    height_ratio = img_height/800
    if image_transform:
      images = image_transform(image)

    images = (images.unsqueeze(0)).to(device)

    backout = backbone(images)

    # The RPN implementation takes as first argument the following image list
    im_lis = ImageList(images, [(800, 1088)]*images.shape[0])
    # Then we pass the image list and the backbone output through the rpn
    rpnout = rpn(im_lis, backout)
    proposals=[proposal[0:keep_topK,:] for proposal in rpnout[0]]
    # A list of features produces by the backbone's FPN levels: list:len(FPN){(bz,256,H_feat,W_feat)}
    fpn_feat_list= list(backout.values())

    feature_vectors = boxhead.MultiScaleRoiAlign(fpn_feat_list, proposals)

    # labels, regressor_targets = boxhead.create_ground_truth(proposals, labels, bboxes)

    class_logits, box_preds = boxhead.forward(feature_vectors)
    # print(boxu)
    boxes, scores, labels = boxhead.postprocess_detections(class_logits, box_preds, proposals, keep_num_postNMS=50)
    num_plot = 1
    boxes_ = boxes[0][:num_plot]
    # print(boxes)
    x1, y1, x2, y2 = boxes_[:, 0], boxes_[:, 1], boxes_[:, 2], boxes_[:, 3]
    
    bbox_array = cv2.rectangle(bbox_array, (int(x1 * width_ratio), int(y1 * height_ratio)), (int(x2 * width_ratio), int(y2 * height_ratio)), (255, 0, 0), 1)
      # print(bbox_array)
    MEAN = torch.tensor([0.485, 0.456, 0.406])
    STD = torch.tensor([0.229, 0.224, 0.225])


    bbox_array[:,:,3] = (bbox_array.max(axis = 2) > 0 ).astype(int) * 255
    # convert overlay of bbox into bytes
    bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
    iobuf = io.BytesIO()
    # format bbox into png for return
    bbox_PIL.save(iobuf, format='png')
    # format return string
    bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))
    # bbox_bytes = bbox_to_bytes(bbox_array)
    # update bbox so next frame gets new overlay
    bbox = bbox_bytes
    boxes = [box.to(device) for box in boxes]
    feature_vectors_2 = model.MultiScaleRoiAlign(fpn_feat_list, boxes) 

    fv2_shape = feature_vectors_2.shape
    # print(fv2_shape)
    # feature_vectors_2 = feature_vectors_2.reshape((fv2_shape[0]*fv2_shape[1], fv2_shape[2], fv2_shape[3], fv2_shape[4]))
    mask_pred = model.forward(feature_vectors_2.squeeze(0))
    boxes = boxes[0]
    # num_plot = 4
    cls_lab = labels[0][num_plot-1].item()-1
    mask_one_cls = mask_pred[:,cls_lab,:,:].unsqueeze(1)
    mask_total = torch.tensor([]).to(device)
    for idx in range(mask_pred.shape[0]):

      # if int(h[idx]) < 2 or int(w[idx]) < 2:
      #     continue
      x1, y1, x2, y2 = tuple(boxes[idx].detach().cpu().numpy()) # x1, x2, y1, y2
      x1, y1, x2, y2 = max(0, int(x1)), max(0, int(y1)), min(int(x2), 1088), min(int(y2), 800)
      h = y2 - y1
      w = x2 - x1
      mask_one = mask_one_cls[idx].unsqueeze(0)               # [1, 1, 28, 28]
      mask_rescaled = F.interpolate(mask_one, size = (h, w), mode='bilinear', align_corners=True).squeeze()   # [h, w]

      # Padding
      p2d = (int(x1), 1088-int(x1)-int(w), int(y1), 800-int(y1)-int(h))
      mask_padded = F.pad(mask_rescaled, p2d).unsqueeze(0)    # [800, 1088]
      mask_total = torch.cat((mask_total,mask_padded), dim=0)
    positive_idx = torch.where(mask_total >= 0.5)
    negative_idx = torch.where(mask_total < 0.5)
    mask_total[positive_idx] = 1
    mask_total[negative_idx] = 0
    mask_transfer = transforms.Resize((480,640))
    mask_total = mask_transfer(mask_total[:num_plot].unsqueeze(1)).squeeze(1).squeeze(0)
    positive_idx2 = torch.where(mask_total >= 0.6)
    negative_idx2 = torch.where(mask_total < 0.6)
    mask_total[positive_idx2] = 1
    mask_total[negative_idx2] = 0
    mask_total = mask_total.type(torch.uint8)
    #  = apply_mask(frame, mask_total, (0,0,255))
    
    mask_array = np.zeros([480,640,4], dtype=np.uint8)
    mask_array[:,:,cls_lab] = mask_total.detach().cpu().numpy()*255
    mask_array[:,:,3] = mask_total.detach().cpu().numpy()*115
    # mask_array[:,:,3] = 1
    mask_PIL = PIL.Image.fromarray(mask_array, 'RGBA')
    iobuf = io.BytesIO()
    # format bbox into png for return
    mask_PIL.save(iobuf, format='png')
    # format return string
    mask_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))
    mask = mask_bytes
    images = images.cpu().squeeze()


    # x = images * STD[:, None, None] + MEAN[:, None, None]
# Out:
# <ipython-input-7-ba23325ac1d3>:75: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   class_logits = softmax(class_logits)
